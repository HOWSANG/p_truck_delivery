# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import os
import requests
import time
from tqdm import tqdm
from datetime import datetime
import geocoder

# %%
# 한글 폰트 설정 (필요한 경우)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
# 엑셀 파일 경로 설정
file_path = "/Users/stella/Documents/03.proj/p_truck_delivery/data/winter_internship_prj_250122_v1.0.xlsx"  # 파일명을 실제 파일 이름으로 변경하세요.

# Excel 파일 읽기 (engine='openpyxl' 명시)
excel_data = pd.ExcelFile(file_path, engine='openpyxl')

# 모든 시트 이름 확인 (선택적으로 확인 가능)
print("Available sheets:", excel_data.sheet_names)

# 두 번째 시트의 데이터 읽기 (시트 인덱스는 0부터 시작)
df = pd.read_excel(file_path, sheet_name=1, engine='openpyxl')  # sheet_name=1은 두 번째 시트를 의미

# 데이터프레임 확인
print(df)
# Out:
# Available sheets: ['info', 'data_sample', 'sample2', 'Analysis']
#         GpsProvider           BookingID Market/Regular   \
# 0     CONSENT TRACK  MVCV0000927/082021          Market
# 1           VAMOSYS  VCV00014271/082021         Regular
# 2     CONSENT TRACK  VCV00014382/082021         Regular
# 3           VAMOSYS  VCV00014743/082021         Regular
# 4           VAMOSYS  VCV00014744/082021         Regular
# ...             ...                 ...             ...
# 6875          JTECH        WDSBKTP42751         Regular
# 6876          JTECH        WDSBKTP43203         Regular
# 6877          JTECH        WDSBKTP43021         Regular
# 6878          JTECH        WDSBKTP42685         Regular
# 6879          JTECH        WDSBKTP42858         Regular
#
#               BookingID_Date  vehicle_no  \
# 0    2020-08-17 14:59:01.000    KA590408
# 1    2020-08-27 16:22:22.827  TN30BC5917
# 2    2020-08-27 17:59:24.987  TN22AR2748
# 3    2020-08-28 00:48:24.503  TN28AQ0781
# 4    2020-08-28 01:23:19.243   TN68F1722
# ...                      ...         ...
# 6875 2019-03-27 17:25:33.000    KA219502
# 6876 2019-03-31 15:02:34.000  KA01AE9163
# 6877 2019-03-29 18:56:26.000  KA01AE9163
# 6878 2019-03-27 08:29:45.000   KA21A3643
# 6879 2019-03-28 17:55:17.000   KA51D1317
#
#                                         Origin_Location  \
# 0                  TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875             Ramamurthy Nagar, Bangalore, Karnataka
# 6876             Ramamurthy Nagar, Bangalore, Karnataka
# 6877               Mugabala, Bangalore Rural, Karnataka
# 6878               Mugabala, Bangalore Rural, Karnataka
# 6879               Mugabala, Bangalore Rural, Karnataka
#
#                                    Destination_Location  \
# 0          ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875            Sahakaranagar P.O, Bangalore, Karnataka
# 6876  Bangalore International Airport, Bangalore, Ka...
# 6877                       Anekal, Bangalore, Karnataka
# 6878                       Anekal, Bangalore, Karnataka
# 6879                       Anekal, Bangalore, Karnataka
#
#                                 Org_lat_lon  \
# 0                           13.1550,80.1960
# 1                           12.8390,79.9540
# 2                           11.8710,79.7390
# 3                           12.8390,79.9540
# 4                           11.8720,79.6320
# ...                                     ...
# 6875  13.007503209603689,77.665098855934886
# 6876  13.007503209603689,77.665098855934886
# 6877  16.560192249175344,80.792293091599547
# 6878  16.560192249175344,80.792293091599547
# 6879  16.560192249175344,80.792293091599547
#
#                                 Des_lat_lon      Data_Ping_time  ...  \
# 0                           12.7400,77.8200 2020-08-24 00:05:09  ...
# 1                           12.8390,79.9540 2020-08-28 12:40:28  ...
# 2                           11.8710,79.7390 2020-08-28 09:05:09  ...
# 3                           12.8390,79.9540 2020-08-28 12:40:31  ...
# 4                           11.8720,79.6320 2020-08-28 12:40:29  ...
# ...                                     ...                 ...  ...
# 6875  13.068901840235711,77.590655738806618 2019-06-14 15:20:12  ...
# 6876  13.196312912801169,77.708156925688726 2019-06-14 15:20:12  ...
# 6877                    12.722686,77.676518 2019-06-14 15:20:12  ...
# 6878  12.896896847817695,77.712223056874862 2019-06-14 15:20:12  ...
# 6879  13.199089183304451,77.708554234959038 2019-06-14 15:20:12  ...
#
#      TRANSPORTATION_DISTANCE_IN_KM             vehicleType  \
# 0                            320.0                     NaN
# 1                            103.0                     NaN
# 2                            300.0                     NaN
# 3                             61.0                     NaN
# 4                            240.0                     NaN
# ...                            ...                     ...
# 6875                          12.0    25 FT Open Body 21MT
# 6876                          31.0  40 FT 3XL Trailer 35MT
# 6877                          49.0  40 FT 3XL Trailer 35MT
# 6878                          49.0  40 FT 3XL Trailer 35MT
# 6879                          49.0  40 FT 3XL Trailer 35MT
#
#      Minimum_kms_to_be_covered_in_a_day Driver_Name  Driver_MobileNo  \
# 0                                   NaN         NaN              NaN
# 1                                   NaN      RAMESH              NaN
# 2                                   NaN        GIRI              NaN
# 3                                   NaN        RAVI              NaN
# 4                                   NaN       TAMIL              NaN
# ...                                 ...         ...              ...
# 6875                                NaN         NaN              NaN
# 6876                                NaN         NaN              NaN
# 6877                                NaN         NaN              NaN
# 6878                                NaN         NaN              NaN
# 6879                                NaN         NaN              NaN
#
#       customerID                          customerNameCode  supplierID  \
# 0     ALLEXCHE45                     Ashok leyland limited  VIJEXHOSR7
# 1     DMREXCHEUX  Daimler india commercial vehicles pvt lt  VJLEXSHE09
# 2     LUTGCCHE06                             Lucas tvs ltd  GSTEXLAK1Q
# 3     DMREXCHEUX  Daimler india commercial vehicles pvt lt  ARVEXNAM09
# 4     LUTGCCHE06                             Lucas tvs ltd  SRTEXKOR96
# ...          ...                                       ...         ...
# 6875  LTLEXMUM40                   Larsen & toubro limited       55556
# 6876  LTLEXMUM40                   Larsen & toubro limited       55556
# 6877  LTLEXMUM40                   Larsen & toubro limited       55556
# 6878  LTLEXMUM40                   Larsen & toubro limited       55556
# 6879  LTLEXMUM40                   Larsen & toubro limited       55556
#
#        supplierNameCode          Material Shipped
# 0       VIJAY TRANSPORT     BRACKET / GRAB HANDLE
# 1          VJ LOGISTICS     ZB MODEL PLATE / 3143
# 2        G.S. TRANSPORT          LETTERING / FUSO
# 3     ARVINTH TRANSPORT  LU STRUT RA / RADIUS ROD
# 4         SR TRANSPORTS      WISHBONE / V ROD/HDT
# ...                 ...                       ...
# 6875     A S TRANSPORTS              TOOL KIT SET
# 6876     A S TRANSPORTS        CONTROL LEVER ASSY
# 6877     A S TRANSPORTS    SPARE PARTS AUTOMOBILE
# 6878     A S TRANSPORTS    SPARE PARTS AUTOMOBILE
# 6879     A S TRANSPORTS    SPARE PARTS AUTOMOBILE
#
# [6880 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   Market/Regular                      6880 non-null   object
#  3   BookingID_Date                      6880 non-null   datetime64[ns]
#  4   vehicle_no                          6880 non-null   object
#  5   Origin_Location                     6880 non-null   object
#  6   Destination_Location                6880 non-null   object
#  7   Org_lat_lon                         6880 non-null   object
#  8   Des_lat_lon                         6880 non-null   object
#  9   Data_Ping_time                      5927 non-null   datetime64[ns]
#  10  Planned_ETA                         6880 non-null   object
#  11  Current_Location                    5916 non-null   object
#  12  DestinationLocation                 6880 non-null   object
#  13  actual_eta                          6843 non-null   object
#  14  Curr_lat                            5927 non-null   float64
#  15  Curr_lon                            5927 non-null   float64
#  16  ontime                              2548 non-null   object
#  17  delay                               4342 non-null   object
#  18  OriginLocation_Code                 6877 non-null   object
#  19  DestinationLocation_Code            6853 non-null   object
#  20  trip_start_date                     6880 non-null   object
#  21  trip_end_date                       6686 non-null   object
#  22  TRANSPORTATION_DISTANCE_IN_KM       6168 non-null   float64
#  23  vehicleType                         6052 non-null   object
#  24  Minimum_kms_to_be_covered_in_a_day  2820 non-null   float64
#  25  Driver_Name                         3451 non-null   object
#  26  Driver_MobileNo                     2691 non-null   float64
#  27  customerID                          6880 non-null   object
#  28  customerNameCode                    6880 non-null   object
#  29  supplierID                          6880 non-null   object
#  30  supplierNameCode                    6880 non-null   object
#  31  Material Shipped                    6880 non-null   object
# dtypes: datetime64[ns](2), float64(5), object(25)
# memory usage: 1.7+ MB

# %% [markdown]
# ### 2. 탐색적 데이터 분석(EDA)

# %% [markdown]
# #### 2.1 컬럼명 정제

# %%
def convert_to_camel_case(column_name):
    # 특수문자를 공백으로 대체하고 공백을 기준으로 분리
    words = ''.join(c if c.isalnum() else ' ' for c in column_name).split()
    
    # 첫 번째 단어는 소문자로, 나머지 단어들은 첫 글자만 대문자로 변환
    return words[0].lower() + ''.join(word.capitalize() for word in words[1:])

# %%
# 데이터프레임의 모든 컬럼명을 camel case로 변환
def convert_columns_to_camel_case(df):
    # 현재 컬럼명과 변환된 컬럼명을 매핑
    column_mapping = {col: convert_to_camel_case(col) for col in df.columns}
    
    # 변경된 컬럼명 출력 (변경 전/후 확인용)
    print("컬럼명 변경 사항:")
    for old_col, new_col in column_mapping.items():
        print(f"{old_col} -> {new_col}")
    
    # 데이터프레임 컬럼명 변경
    df.rename(columns=column_mapping, inplace=True)
    
    return df

# %%
# 컬럼명을 camel case로 변환
df = convert_columns_to_camel_case(df)

# 결과 확인
print("\n변환된 컬럼명:")
print(df.columns.tolist())
# Out:
# 컬럼명 변경 사항:
# GpsProvider -> gpsprovider
# BookingID -> bookingid
# Market/Regular  -> marketRegular
# BookingID_Date -> bookingidDate
# vehicle_no -> vehicleNo
# Origin_Location -> originLocation
# Destination_Location -> destinationLocation
# Org_lat_lon -> orgLatLon
# Des_lat_lon -> desLatLon
# Data_Ping_time -> dataPingTime
# Planned_ETA -> plannedEta
# Current_Location -> currentLocation
# DestinationLocation -> destinationlocation
# actual_eta -> actualEta
# Curr_lat -> currLat
# Curr_lon -> currLon
# ontime -> ontime
# delay -> delay
# OriginLocation_Code -> originlocationCode
# DestinationLocation_Code -> destinationlocationCode
# trip_start_date -> tripStartDate
# trip_end_date -> tripEndDate
# TRANSPORTATION_DISTANCE_IN_KM -> transportationDistanceInKm
# vehicleType -> vehicletype
# Minimum_kms_to_be_covered_in_a_day -> minimumKmsToBeCoveredInADay
# Driver_Name -> driverName
# Driver_MobileNo -> driverMobileno
# customerID -> customerid
# customerNameCode -> customernamecode
# supplierID -> supplierid
# supplierNameCode -> suppliernamecode
# Material Shipped -> materialShipped
#
# 변환된 컬럼명:
# ['gpsprovider', 'bookingid', 'marketRegular', 'bookingidDate', 'vehicleNo', 'originLocation', 'destinationLocation', 'orgLatLon', 'desLatLon', 'dataPingTime', 'plannedEta', 'currentLocation', 'destinationlocation', 'actualEta', 'currLat', 'currLon', 'ontime', 'delay', 'originlocationCode', 'destinationlocationCode', 'tripStartDate', 'tripEndDate', 'transportationDistanceInKm', 'vehicletype', 'minimumKmsToBeCoveredInADay', 'driverName', 'driverMobileno', 'customerid', 'customernamecode', 'supplierid', 'suppliernamecode', 'materialShipped']

# %% [markdown]
# #### 2.2 시간 컬럼 정제
#     - tripStartDate, tripEndDate 간의 소요시간 생성

# %%
# 운행시간 처리
df['tripStartDate'] = pd.to_datetime(df['tripStartDate'])
df['tripEndDate'] = pd.to_datetime(df['tripEndDate'])
df['tripDuration'] = (df['tripEndDate'] - df['tripStartDate']).dt.total_seconds() / 3600  # 시간 단위

# %%
# 분석에 필요한 feature 정보 추출
List = ['gpsprovider','bookingid', 'bookingidDate', 'vehicleNo', 'originLocation', 'destinationLocation', 'orgLatLon', 'desLatLon', 'plannedEta'
        , 'currentLocation', 'destinationlocation', 'actualEta', 'ontime', 'delay', 'tripStartDate', 'tripEndDate', 'tripDuration', 'transportationDistanceInKm'
        ,'minimumKmsToBeCoveredInADay', 'customerid', 'customernamecode']
# test=df[List].copy()
test=df.copy()

# %% [markdown]
# #### 2.3 기초분석

# %%
def analyze_dataframe(df):
    """
    데이터프레임 기초분석 함수
    """
    print("="*50)
    print("1. 데이터프레임 기본 정보")
    print("="*50)
    print(f"데이터 크기: {df.shape}")
    print("\n데이터 타입 정보:")
    print(df.info())
    
    print("\n"+"="*50)
    print("2. 결측치 분석")
    print("="*50)
    # 결측치 개수와 비율 계산
    missing_values = df.isnull().sum()
    missing_ratio = (df.isnull().sum() / len(df)) * 100
    
    missing_info = pd.DataFrame({
        '결측치 개수': missing_values,
        '결측치 비율(%)': missing_ratio.round(2)
    })
    print(missing_info[missing_info['결측치 개수'] > 0])  # 결측치가 있는 컬럼만 출력
    
    print("\n"+"="*50)
    print("3. 수치형 변수 기초 통계량")
    print("="*50)
    numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
    print(df[numeric_columns].describe())
    
    print("\n"+"="*50)
    print("4. 범주형 변수 분포")
    print("="*50)
    categorical_columns = df.select_dtypes(include=['object']).columns
    for col in categorical_columns:
        print(f"\n{col} 변수의 고유값 개수: {df[col].nunique()}")
        print(f"\n상위 5개 빈도:")
        print(df[col].value_counts().head())

# %%
analyze_dataframe(test)
# Out:
# ==================================================
# 1. 데이터프레임 기본 정보
# ==================================================
# 데이터 크기: (6880, 33)
#
# 데이터 타입 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gpsprovider                  5927 non-null   object
#  1   bookingid                    6880 non-null   object
#  2   marketRegular                6880 non-null   object
#  3   bookingidDate                6880 non-null   datetime64[ns]
#  4   vehicleNo                    6880 non-null   object
#  5   originLocation               6880 non-null   object
#  6   destinationLocation          6880 non-null   object
#  7   orgLatLon                    6880 non-null   object
#  8   desLatLon                    6880 non-null   object
#  9   dataPingTime                 5927 non-null   datetime64[ns]
#  10  plannedEta                   6880 non-null   object
#  11  currentLocation              5916 non-null   object
#  12  destinationlocation          6880 non-null   object
#  13  actualEta                    6843 non-null   object
#  14  currLat                      5927 non-null   float64
#  15  currLon                      5927 non-null   float64
#  16  ontime                       2548 non-null   object
#  17  delay                        4342 non-null   object
#  18  originlocationCode           6877 non-null   object
#  19  destinationlocationCode      6853 non-null   object
#  20  tripStartDate                6880 non-null   datetime64[ns]
#  21  tripEndDate                  6686 non-null   datetime64[ns]
#  22  transportationDistanceInKm   6168 non-null   float64
#  23  vehicletype                  6052 non-null   object
#  24  minimumKmsToBeCoveredInADay  2820 non-null   float64
#  25  driverName                   3451 non-null   object
#  26  driverMobileno               2691 non-null   float64
#  27  customerid                   6880 non-null   object
#  28  customernamecode             6880 non-null   object
#  29  supplierid                   6880 non-null   object
#  30  suppliernamecode             6880 non-null   object
#  31  materialShipped              6880 non-null   object
#  32  tripDuration                 6686 non-null   float64
# dtypes: datetime64[ns](4), float64(6), object(23)
# memory usage: 1.7+ MB
# None
#
# ==================================================
# 2. 결측치 분석
# ==================================================
#                              결측치 개수  결측치 비율(%)
# gpsprovider                     953      13.85
# dataPingTime                    953      13.85
# currentLocation                 964      14.01
# actualEta                        37       0.54
# currLat                         953      13.85
# currLon                         953      13.85
# ontime                         4332      62.97
# delay                          2538      36.89
# originlocationCode                3       0.04
# destinationlocationCode          27       0.39
# tripEndDate                     194       2.82
# transportationDistanceInKm      712      10.35
# vehicletype                     828      12.03
# minimumKmsToBeCoveredInADay    4060      59.01
# driverName                     3429      49.84
# driverMobileno                 4189      60.89
# tripDuration                    194       2.82
#
# ==================================================
# 3. 수치형 변수 기초 통계량
# ==================================================
#            currLat      currLon  transportationDistanceInKm  \
# count  5927.000000  5927.000000                 6168.000000
# mean     18.679995    78.759745                  553.856282
# std       6.075561     4.216357                  758.981836
# min       8.166790    69.657698                    0.000000
# 25%      12.871868    76.891857                   40.000000
# 50%      17.470922    77.843340                  160.000000
# 75%      23.202009    80.018999                  900.000000
# max      32.367928    95.529550                 2954.700000
#
#        minimumKmsToBeCoveredInADay  driverMobileno  tripDuration
# count                  2820.000000    2.691000e+03   6686.000000
# mean                    250.239362    8.598981e+09    116.989097
# std                      24.315485    1.131669e+09    263.808597
# min                       0.000000    6.000546e+09  -6380.789167
# 25%                     250.000000    7.651505e+09     22.693209
# 50%                     250.000000    8.930762e+09     83.785000
# 75%                     250.000000    9.634981e+09    162.301389
# max                     275.000000    1.000000e+10   2948.266667
#
# ==================================================
# 4. 범주형 변수 분포
# ==================================================
#
# gpsprovider 변수의 고유값 개수: 29
#
# 상위 5개 빈도:
# gpsprovider
# CONSENT TRACK    3859
# VAMOSYS           788
# EKTA              322
# JTECH             241
# MANUAL            219
# Name: count, dtype: int64
#
# bookingid 변수의 고유값 개수: 6875
#
# 상위 5개 빈도:
# bookingid
# MVCV0000798/082021    3
# AEIBK1902026          2
# MVCV0000759/082021    2
# VCV00014072/082021    2
# MVCV0000927/082021    1
# Name: count, dtype: int64
#
# marketRegular 변수의 고유값 개수: 2
#
# 상위 5개 빈도:
# marketRegular
# Regular    6811
# Market       69
# Name: count, dtype: int64
#
# vehicleNo 변수의 고유값 개수: 2325
#
# 상위 5개 빈도:
# vehicleNo
# TS15UC9341    37
# KA21A5090     31
# KA01AF0114    31
# KA21A3643     30
# TS15UD3698    29
# Name: count, dtype: int64
#
# originLocation 변수의 고유값 개수: 180
#
# 상위 5개 빈도:
# originLocation
# Mugabala, Bangalore Rural, Karnataka                        572
# Shive, Pune, Maharashtra                                    428
# Sedarapet, India                                            409
# DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,TAMIL NADU    341
# Kollur, Medak, Telangana                                    333
# Name: count, dtype: int64
#
# destinationLocation 변수의 고유값 개수: 520
#
# 상위 5개 빈도:
# destinationLocation
# DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,TAMIL NADU    342
# Singaperumalkoil, Kanchipuram, Tamil Nadu                   252
# Bangalore International Airport, Bangalore, Karnataka       243
# Pondur, Kanchipuram, Tamil Nadu                             209
# Khorajnanoda, Ahmedabad, Gujarat                            182
# Name: count, dtype: int64
#
# orgLatLon 변수의 고유값 개수: 173
#
# 상위 5개 빈도:
# orgLatLon
# 16.560192249175344,80.792293091599547    1189
# 18.750621,73.87719                        428
# 12.0001,79.74839949999999                 409
# 26.192290403509681,91.751276775362513     380
# 12.8390,79.9540                           342
# Name: count, dtype: int64
#
# desLatLon 변수의 고유값 개수: 522
#
# 상위 5개 빈도:
# desLatLon
# 12.8390,79.9540                          342
# 12.786517,79.975221                      252
# 13.199089183304451,77.708554234959038    227
# 12.930429,79.931163                      209
# 22.961777,72.094219                      182
# Name: count, dtype: int64
#
# plannedEta 변수의 고유값 개수: 6295
#
# 상위 5개 빈도:
# plannedEta
# 2020-08-13 09:52:17    14
# 2020-08-03 08:16:10    10
# 2020-08-22 16:14:20     8
# 2020-07-11 15:36:16     8
# 2020-07-10 13:15:37     8
# Name: count, dtype: int64
#
# currentLocation 변수의 고유값 개수: 2567
#
# 상위 5개 빈도:
# currentLocation
# Perumalpattu - Kottamedu Rd, Oragadam Industrial Corridor, Vattambakkam R.F., Tamil Nadu 631605, India             198
# Unnamed Road, Chharodi, Gujarat 382170, India                                                                      102
# Unnamed Road, Maraimalai Nagar, Tamil Nadu 603209, India                                                            96
# Singaperumal Koil - Sriperumbudur Rd, Oragadam Industrial Corridor, Vattambakkam R.F., Tamil Nadu 631605, India     94
# Unnamed Road, Velimela, Hyderabad, Telangana 502300, India                                                          59
# Name: count, dtype: int64
#
# destinationlocation 변수의 고유값 개수: 520
#
# 상위 5개 빈도:
# destinationlocation
# DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,TAMIL NADU    342
# Singaperumalkoil, Kanchipuram, Tamil Nadu                   252
# Bangalore International Airport, Bangalore, Karnataka       243
# Pondur, Kanchipuram, Tamil Nadu                             209
# Khorajnanoda, Ahmedabad, Gujarat                            182
# Name: count, dtype: int64
#
# actualEta 변수의 고유값 개수: 6729
#
# 상위 5개 빈도:
# actualEta
# 2020-06-19 18:52:00    6
# 2020-07-31 13:13:00    5
# 2019-05-24 16:16:00    5
# 2020-07-29 19:37:00    5
# 2020-07-23 02:09:00    4
# Name: count, dtype: int64
#
# ontime 변수의 고유값 개수: 1
#
# 상위 5개 빈도:
# ontime
# G    2548
# Name: count, dtype: int64
#
# delay 변수의 고유값 개수: 1
#
# 상위 5개 빈도:
# delay
# R    4342
# Name: count, dtype: int64
#
# originlocationCode 변수의 고유값 개수: 178
#
# 상위 5개 빈도:
# originlocationCode
# V0048673         1186
# CHESEDLTLCCA1     410
# CHEORADMRCCB1     393
# V0045300          380
# GURJMATVSHUA1     264
# Name: count, dtype: int64
#
# destinationlocationCode 변수의 고유값 개수: 478
#
# 상위 5개 빈도:
# destinationlocationCode
# CHEMMNFILCCA1    259
# CHEMATDMROPA7    242
# LE005770         227
# CHEORADMRCCB1    189
# GURJMATVSHUA1    166
# Name: count, dtype: int64
#
# vehicletype 변수의 고유값 개수: 44
#
# 상위 5개 빈도:
# vehicletype
# 40 FT 3XL Trailer 35MT                      2575
# 32 FT Multi-Axle 14MT - HCV                  957
# 40 FT Flat Bed Multi-Axle 27MT - Trailer     670
# 32 FT Single-Axle 7MT - HCV                  491
# 28 FT Open Body 25MT                         171
# Name: count, dtype: int64
#
# driverName 변수의 고유값 개수: 1355
#
# 상위 5개 빈도:
# driverName
# MANU        60
# MURUGAN     53
# RAJA        49
# SUDHAKAR    48
# RAVI        30
# Name: count, dtype: int64
#
# customerid 변수의 고유값 개수: 39
#
# 상위 5개 빈도:
# customerid
# LTLEXMUM40    4092
# FILEXCHE19     657
# DMREXCHEUX     588
# ALLEXCHE45     251
# LUTGCCHE06     222
# Name: count, dtype: int64
#
# customernamecode 변수의 고유값 개수: 39
#
# 상위 5개 빈도:
# customernamecode
# Larsen & toubro limited                     4092
# Ford india private limited                   657
# Daimler india commercial vehicles pvt lt     588
# Lucas tvs ltd                                222
# Ashok leyland limited                        211
# Name: count, dtype: int64
#
# supplierid 변수의 고유값 개수: 321
#
# 상위 5개 빈도:
# supplierid
# 999      742
# 55471    496
# 55556    496
# 67779    247
# 60901    224
# Name: count, dtype: int64
#
# suppliernamecode 변수의 고유값 개수: 309
#
# 상위 5개 빈도:
# suppliernamecode
# Unknown                            742
# SUNITA CARRIERS PRIVATE LIMITED    496
# A S TRANSPORTS                     496
# EKTA TRANSPORT COMPANY             248
# K.RAMACHANDRAN TRANSPORTS          224
# Name: count, dtype: int64
#
# materialShipped 변수의 고유값 개수: 1407
#
# 상위 5개 빈도:
# materialShipped
# AUTO PARTS                       1510
# GRS STARTER                       252
# M70 STARTER MOTOR 12V 0.9KW       215
# EMPTY TRAYS                       172
# SIA114 12V 70A ALTERNATOR         159
# Name: count, dtype: int64

# %%
# 새로운 Unique Key 생성
def create_unique_key(df):
    # bookingid와 customerid를 문자열로 변환하고 결합
    # df['uniqueKey'] = df['gpsprovider'].astype(str)+ '_' + df['bookingid'].astype(str) + '_' + df['customerid'].astype(str)
    df['uniqueKey'] = df['bookingid'].astype(str) + '_' + df['customerid'].astype(str) + '_' + df['gpsprovider'].astype(str)
    
    # uniqueKey의 고유성 확인
    total_rows = len(df)
    unique_keys = len(df['uniqueKey'].unique())
    
    print(f"전체 행 수: {total_rows}")
    print(f"고유 키 수: {unique_keys}")
    print(f"중복 키 수: {total_rows - unique_keys}")
    
    # 중복된 키가 있다면 중복 케이스 출력
    if total_rows != unique_keys:
        print("\n중복된 키 목록:")
        duplicates = df[df['uniqueKey'].duplicated(keep=False)].sort_values('uniqueKey')
        print(duplicates[['uniqueKey', 'bookingid', 'customerid', 'gpsprovider']])
        
        # 중복 해결을 위해 순번 추가
        df['uniqueKey'] = df.groupby('uniqueKey').cumcount().astype(str) + '_' + df['uniqueKey']
    
    return df

# 함수 실행
test = create_unique_key(test)

# 결과 확인
print("\n최종 Unique Key 확인:")
print(f"전체 행 수: {len(test)}")
print(f"고유 키 수: {len(test['uniqueKey'].unique())}")

# 샘플 데이터 확인
print("\n생성된 Unique Key 샘플:")
print(test[['uniqueKey', 'bookingid', 'customerid', 'gpsprovider']].head())
# Out:
# 전체 행 수: 6880
# 고유 키 수: 6880
# 중복 키 수: 0
#
# 최종 Unique Key 확인:
# 전체 행 수: 6880
# 고유 키 수: 6880
#
# 생성된 Unique Key 샘플:
#                                      uniqueKey           bookingid  \
# 0  MVCV0000927/082021_ALLEXCHE45_CONSENT TRACK  MVCV0000927/082021
# 1        VCV00014271/082021_DMREXCHEUX_VAMOSYS  VCV00014271/082021
# 2  VCV00014382/082021_LUTGCCHE06_CONSENT TRACK  VCV00014382/082021
# 3        VCV00014743/082021_DMREXCHEUX_VAMOSYS  VCV00014743/082021
# 4        VCV00014744/082021_LUTGCCHE06_VAMOSYS  VCV00014744/082021
#
#    customerid    gpsprovider
# 0  ALLEXCHE45  CONSENT TRACK
# 1  DMREXCHEUX        VAMOSYS
# 2  LUTGCCHE06  CONSENT TRACK
# 3  DMREXCHEUX        VAMOSYS
# 4  LUTGCCHE06        VAMOSYS

# %%
def create_unified_delivery_status(df):
    """
    ontime('G')와 delay('R') 컬럼을 하나의 배송 상태 컬럼으로 통합
    
    Parameters:
        df: DataFrame with 'ontime' and 'delay' columns
    
    Returns:
        DataFrame with new 'delivery_status' column
    """
    # 기존 값 확인
    print("=== 기존 데이터 값 분포 ===")
    print("\nontime 컬럼 값 분포:")
    print(df['ontime'].value_counts())
    print("\ndelay 컬럼 값 분포:")
    print(df['delay'].value_counts())
    
    # 새로운 배송 상태 컬럼 생성
    df['delivery_status'] = 'UNKNOWN'  # 기본값
    
    # ontime이 'G'인 경우 'ON_TIME'으로 설정
    df.loc[df['ontime'] == 'G', 'delivery_status'] = 'ontime'
    
    # delay가 'R'인 경우 'DELAYED'로 설정
    df.loc[df['delay'] == 'R', 'delivery_status'] = 'delay'
    
    # 데이터 검증
    # ontime이 'G'인데 delay도 'R'인 경우 확인 (모순된 데이터)
    contradictions = df[(df['ontime'] == 'G') & (df['delay'] == 'R')]
    if len(contradictions) > 0:
        print("\n=== 주의: 모순된 데이터 발견 ===")
        print(f"모순된 데이터 수: {len(contradictions)}")
        print("\n모순된 데이터 샘플:")
        print(contradictions[['ontime', 'delay', 'delivery_status']].head())
    
    # 결과 확인
    print("\n=== 새로운 배송 상태 분포 ===")
    print(df['delivery_status'].value_counts())
    
    # 숫자형 컬럼도 추가 (머신러닝 모델링용)
    df['delivery_status_code'] = df['delivery_status'].map({
        'ontime': 0,
        'delay': 1,
        'UNKNOWN': -1
    })
    
    return df

# %%
test=create_unified_delivery_status(test)
# Out:
# === 기존 데이터 값 분포 ===
#
# ontime 컬럼 값 분포:
# ontime
# G    2548
# Name: count, dtype: int64
#
# delay 컬럼 값 분포:
# delay
# R    4342
# Name: count, dtype: int64
#
# === 주의: 모순된 데이터 발견 ===
# 모순된 데이터 수: 24
#
# 모순된 데이터 샘플:
#      ontime delay delivery_status
# 5820      G     R           delay
# 5821      G     R           delay
# 5822      G     R           delay
# 5823      G     R           delay
# 5824      G     R           delay
#
# === 새로운 배송 상태 분포 ===
# delivery_status
# delay      4342
# ontime     2524
# UNKNOWN      14
# Name: count, dtype: int64

# %%
test[test['delivery_status_code']==-1]
# Out:
#         gpsprovider     bookingid marketRegular       bookingidDate  \
# 1514   VINAYAKA_TVS  AEIBK2025104       Regular 2020-08-07 11:27:20
# 1595        VAMOSYS  AEIBK2025125       Regular 2020-08-07 15:56:38
# 2725  CONSENT TRACK  AEIBK2021746       Regular 2020-06-30 21:47:14
# 2732  CONSENT TRACK  AEIBK2021951       Regular 2020-07-03 17:44:03
# 2733           EKTA  AEIBK2021962       Regular 2020-07-03 22:44:53
# 2734  CONSENT TRACK  AEIBK2022212       Regular 2020-07-08 11:53:00
# 5379  CONSENT TRACK  AEIBK1901943       Regular 2019-10-20 16:36:54
# 5384         MANUAL  AEIBK1901336       Regular 2019-10-15 13:08:50
# 5390         MANUAL  AEIBK1901349       Regular 2019-10-15 17:49:14
# 5412         MANUAL  AEIBK1901351       Regular 2019-10-15 17:48:55
# 5413         MANUAL  AEIBK1901139       Regular 2019-10-12 14:02:31
# 5438         MANUAL  AEIBK1900877       Regular 2019-10-10 10:06:40
# 5439         MANUAL  AEIBK1900879       Regular 2019-10-10 10:07:38
# 5440         MANUAL  AEIBK1900880       Regular 2019-10-10 10:07:41
#
#        vehicleNo                                 originLocation  \
# 1514   KA52A5807             Onnalvadi, Krishnagiri, Tamil Nadu
# 1595   GJ02Z0239                       Kalri, Mahesana, Gujarat
# 2725  DL01GC5983  Peenya Small Industries, Bangalore, Karnataka
# 2732  DL01GC6187  Peenya Small Industries, Bangalore, Karnataka
# 2733   HR47D0664       Irungattukottai, Kanchipuram, Tamil Nadu
# 2734  RJ14GF3519  Peenya Small Industries, Bangalore, Karnataka
# 5379  KA01AE9163           Mugabala, Bangalore Rural, Karnataka
# 5384   TN52U1029      Adavipalem, West Godavari, Andhra Pradesh
# 5390  AP16TH6969            Nidamanuru, Krishna, Andhra Pradesh
# 5412  AP16TY1967            Nidamanuru, Krishna, Andhra Pradesh
# 5413   TN34W4267              Tiruvuru, Krishna, Andhra Pradesh
# 5438   HR47A2362           Mugabala, Bangalore Rural, Karnataka
# 5439    KA535220           Mugabala, Bangalore Rural, Karnataka
# 5440   KA53A1845           Mugabala, Bangalore Rural, Karnataka
#
#                                 destinationLocation  \
# 1514                       Shive, Pune, Maharashtra
# 1595                     Solgam, Ahmedabad, Gujarat
# 2725                     Dhatir, Faridabad, Haryana
# 2732                     Dhatir, Faridabad, Haryana
# 2733                     Dhatir, Faridabad, Haryana
# 2734         Mahindra World City, Jaipur, Rajasthan
# 5379                   Anekal, Bangalore, Karnataka
# 5384              Parandur, Kanchipuram, Tamil Nadu
# 5390            Apsp Colony, Guntur, Andhra Pradesh
# 5412            Apsp Colony, Guntur, Andhra Pradesh
# 5413       Malleboinpally, Mahabub Nagar, Telangana
# 5438  Peenya Small Industries, Bangalore, Karnataka
# 5439  Peenya Small Industries, Bangalore, Karnataka
# 5440  Peenya Small Industries, Bangalore, Karnataka
#
#                                   orgLatLon  \
# 1514                    12.683589,77.859239
# 1595                      23.5159,72.077925
# 2725                    13.025282,77.510345
# 2732                    13.025282,77.510345
# 2733                    13.010768,79.993135
# 2734                    13.025282,77.510345
# 5379  16.560192249175344,80.792293091599547
# 5384                     16.510615,81.75956
# 5390                    16.500876,80.760239
# 5412                    16.500876,80.760239
# 5413                    17.105934,80.605204
# 5438  12.992699792116747,77.803841411108593
# 5439  12.992699792116747,77.803841411108593
# 5440  12.992699792116747,77.803841411108593
#
#                                   desLatLon        dataPingTime  ...  \
# 1514                     18.750621,73.87719 2020-08-11 14:45:25  ...
# 1595                    23.338649,71.975699 2020-08-10 09:25:17  ...
# 2725                    28.192852,77.249137 2020-07-04 10:25:10  ...
# 2732                    28.192852,77.249137 2020-07-08 09:25:09  ...
# 2733                    28.192852,77.249137 2020-07-09 11:00:18  ...
# 2734                    27.033987,75.776267 2020-07-08 11:05:08  ...
# 5379  12.777874729699617,77.642275537347089 2019-10-22 10:10:15  ...
# 5384                     12.890556,79.72877 2019-10-16 06:55:01  ...
# 5390                    16.449872,80.532732 2019-10-16 06:50:00  ...
# 5412                    16.449872,80.532732 2019-10-16 06:55:01  ...
# 5413                    16.783108,78.192413 2019-10-15 17:15:03  ...
# 5438  13.196312912801169,77.708156925688726 2019-10-11 02:54:58  ...
# 5439  13.196312912801169,77.708156925688726 2019-10-11 02:54:58  ...
# 5440  13.196312912801169,77.708156925688726 2019-10-11 02:59:59  ...
#
#      driverMobileno  customerid           customernamecode supplierid  \
# 1514   9.113995e+09  NEMEXGURH5    Neel metal products ltd      67992
# 1595   8.238666e+09  GTKEXGURJS      G-tekt india pvt ltd.      81143
# 2725   9.813299e+09  WENEXBAN18  Wipro enterprises pvt ltd      68912
# 2732   8.302295e+09  WENEXBAN18  Wipro enterprises pvt ltd      68912
# 2733   7.082423e+09  WENEXBAN18  Wipro enterprises pvt ltd        999
# 2734   8.168428e+09  WENEXBAN18  Wipro enterprises pvt ltd      68912
# 5379            NaN  LTLEXMUM40    Larsen & toubro limited      55556
# 5384            NaN  LTLEXMUM40    Larsen & toubro limited      63682
# 5390            NaN  LTLEXMUM40    Larsen & toubro limited      63916
# 5412            NaN  LTLEXMUM40    Larsen & toubro limited      63916
# 5413            NaN  LTLEXMUM40    Larsen & toubro limited      63682
# 5438            NaN  LTLEXMUM40    Larsen & toubro limited      55471
# 5439            NaN  LTLEXMUM40    Larsen & toubro limited      55471
# 5440            NaN  LTLEXMUM40    Larsen & toubro limited      55471
#
#                       suppliernamecode                 materialShipped  \
# 1514           SRI VINAYAKA  TRANSPORT                      AUTO PARTS
# 1595            NEW DWARKESH TRANSPORT                           SHAFT
# 2725  JUPITER EXPRESS CARRIER PVT. LTD                      AUTO PARTS
# 2732  JUPITER EXPRESS CARRIER PVT. LTD           NECK COMP,FUEL FILLER
# 2733                           Unknown                     89210M68P20
# 2734  JUPITER EXPRESS CARRIER PVT. LTD                      AUTO PARTS
# 5379                    A S TRANSPORTS                EMPTY LEAD COVER
# 5384  MULURA LOGISTICS PRIVATE LIMITDE               GRP6A-SLEEVE PACK
# 5390              SHRI SAI ENTERPRISES               PLASTIC SEPERATER
# 5412              SHRI SAI ENTERPRISES           RECTIFIER ARRANGEMENT
# 5413  MULURA LOGISTICS PRIVATE LIMITDE  RECTIFIER ASSY - M STAR SIA114
# 5438   SUNITA CARRIERS PRIVATE LIMITED           HOS ASY-OIL COOL INLT
# 5439   SUNITA CARRIERS PRIVATE LIMITED          HOS & CLMP ASY RAD LWR
# 5440   SUNITA CARRIERS PRIVATE LIMITED          HOS ASY ENG COOL RESVR
#
#      tripDuration                              uniqueKey delivery_status  \
# 1514    99.127778   AEIBK2025104_NEMEXGURH5_VINAYAKA_TVS         UNKNOWN
# 1595    65.489444        AEIBK2025125_GTKEXGURJS_VAMOSYS         UNKNOWN
# 2725   687.829444  AEIBK2021746_WENEXBAN18_CONSENT TRACK         UNKNOWN
# 2732   137.632500  AEIBK2021951_WENEXBAN18_CONSENT TRACK         UNKNOWN
# 2733   132.618611           AEIBK2021962_WENEXBAN18_EKTA         UNKNOWN
# 2734    23.483333  AEIBK2022212_WENEXBAN18_CONSENT TRACK         UNKNOWN
# 5379    41.368333  AEIBK1901943_LTLEXMUM40_CONSENT TRACK         UNKNOWN
# 5384   188.986111         AEIBK1901336_LTLEXMUM40_MANUAL         UNKNOWN
# 5390   140.596111         AEIBK1901349_LTLEXMUM40_MANUAL         UNKNOWN
# 5412    81.568056         AEIBK1901351_LTLEXMUM40_MANUAL         UNKNOWN
# 5413   259.941389         AEIBK1901139_LTLEXMUM40_MANUAL         UNKNOWN
# 5438   158.705556         AEIBK1900877_LTLEXMUM40_MANUAL         UNKNOWN
# 5439   158.689444         AEIBK1900879_LTLEXMUM40_MANUAL         UNKNOWN
# 5440   156.505278         AEIBK1900880_LTLEXMUM40_MANUAL         UNKNOWN
#
#      delivery_status_code
# 1514                   -1
# 1595                   -1
# 2725                   -1
# 2732                   -1
# 2733                   -1
# 2734                   -1
# 5379                   -1
# 5384                   -1
# 5390                   -1
# 5412                   -1
# 5413                   -1
# 5438                   -1
# 5439                   -1
# 5440                   -1
#
# [14 rows x 36 columns]

# %%
# 데이터 품질 검증 함수
def validate_delivery_status(df):
    """
    통합된 배송 상태 데이터의 품질 검증
    """
    print("=== 데이터 품질 검증 ===")
    
    # 전체 레코드 수
    total_records = len(df)
    print(f"\n전체 레코드 수: {total_records}")
    
    # 각 상태별 건수와 비율
    status_counts = df['delivery_status'].value_counts()
    status_percentages = (status_counts / total_records * 100).round(2)
    
    print("\n배송 상태별 분포:")
    for status in status_counts.index:
        print(f"{status}: {status_counts[status]} 건 ({status_percentages[status]}%)")
    
    # UNKNOWN 상태 확인
    unknown_records = df[df['delivery_status'] == 'UNKNOWN']
    if len(unknown_records) > 0:
        print("\n=== UNKNOWN 상태 데이터 샘플 ===")
        print(unknown_records[['ontime', 'delay', 'delivery_status']].head())
    
    return status_counts, status_percentages

# %%
validate_delivery_status(test)
# Out:
# === 데이터 품질 검증 ===
#
# 전체 레코드 수: 6880
#
# 배송 상태별 분포:
# delay: 4342 건 (63.11%)
# ontime: 2524 건 (36.69%)
# UNKNOWN: 14 건 (0.2%)
#
# === UNKNOWN 상태 데이터 샘플 ===
#      ontime delay delivery_status
# 1514    NaN   NaN         UNKNOWN
# 1595    NaN   NaN         UNKNOWN
# 2725    NaN   NaN         UNKNOWN
# 2732    NaN   NaN         UNKNOWN
# 2733    NaN   NaN         UNKNOWN
# (delivery_status
#  delay      4342
#  ontime     2524
#  UNKNOWN      14
#  Name: count, dtype: int64,
#  delivery_status
#  delay      63.11
#  ontime     36.69
#  UNKNOWN     0.20
#  Name: count, dtype: float64)

# %% [markdown]
# #### Key 결합 작업하기

# %%
# test.to_excel('truck_unique_key_data_250131_v1.0.xlsx', index=False)

# %% [markdown]
# ### 3. mapBox API를 이용한 위치정보 정제

# %%
# MapBox 액세스 토큰 설정
MAPBOX_ACCESS_TOKEN = ""

# %% [markdown]
# #### 3.1 위도, 경도 분리

# %%
# 위도, 경도 분리 함수
def split_lat_lon(coord_str):
    """
    '위도,경도' 형식의 문자열을 분리하여 위도와 경도를 반환
    """
    try:
        lat, lon = map(float, coord_str.split(','))
        return pd.Series({'latitude': lat, 'longitude': lon})
    except:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
# orgLatLon 컬럼을 위도, 경도로 분리
test[['org_latitude', 'org_longitude']] = test['orgLatLon'].apply(split_lat_lon)

# desLatLon 컬럼을 위도, 경도로 분리
test[['des_latitude', 'des_longitude']] = test['desLatLon'].apply(split_lat_lon)

# %%
test.head(2)
# Out:
#      gpsprovider           bookingid           bookingidDate   vehicleNo  \
# 0  CONSENT TRACK  MVCV0000927/082021 2020-08-17 14:59:01.000    KA590408
# 1        VAMOSYS  VCV00014271/082021 2020-08-27 16:22:22.827  TN30BC5917
#
#                                       originLocation  \
# 0               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
#
#                                  destinationLocation        orgLatLon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
#
#          desLatLon                  plannedEta  \
# 0  12.7400,77.8200         2020-08-21 18:59:01
# 1  12.8390,79.9540  2020-08-31 20:22:22.827000
#
#                                      currentLocation  ...  customerid  \
# 0  Vaniyambadi Rd, Valayambattu, Tamil Nadu 63575...  ...  ALLEXCHE45
# 1  Unnamed Road, Oragadam Industrial Corridor, Va...  ...  DMREXCHEUX
#
#                            customernamecode  \
# 0                     Ashok leyland limited
# 1  Daimler india commercial vehicles pvt lt
#
#                                      uniqueKey delivery_status  \
# 0  CONSENT TRACK_MVCV0000927/082021_ALLEXCHE45           delay
# 1        VAMOSYS_VCV00014271/082021_DMREXCHEUX          ontime
#
#   delivery_status_code org_latitude  org_longitude  \
# 0                    1       13.155         80.196
# 1                    0       12.839         79.954
#
#                                   org_locationDetail  des_latitude  \
# 0  Vanagaram - Ambathur - Puzhal Road, 수라페트, 6000...        12.740
# 1  Singaperumalkoil - Sriperumbudur - Thiruvallur...        12.839
#
#   des_longitude
# 0        77.820
# 1        79.954
#
# [2 rows x 29 columns]

# %%
# MapBox API를 사용한 reverse geocoding 함수
def get_location_info(lat, lon, access_token):
    """
    MapBox API를 사용하여 위도/경도 기반 위치 정보 조회
    """
    base_url = "https://api.mapbox.com/geocoding/v5/mapbox.places"
    
    try:
        url = f"{base_url}/{lon},{lat}.json?access_token={access_token}&language=ko"
        response = requests.get(url)
        data = response.json()
        
        if data.get('features'):
            # 첫 번째 결과의 place_name 반환
            return data['features'][0]['place_name']
        return None
    except Exception as e:
        print(f"에러 발생: {e}")
        return None

# %%
# 위치 정보 조회 및 새 컬럼 추가
def get_all_locations(df, access_token):
    """
    데이터프레임의 모든 위치에 대한 정보 조회
    """
    locations = []
    for idx, row in df.iterrows():
        if pd.notna(row['org_latitude']) and pd.notna(row['org_longitude']):
            location = get_location_info(row['org_latitude'], row['org_longitude'], access_token)
            locations.append(location)
            
            # API 호출 제한을 위한 지연
            time.sleep(0.1)  # 100ms 대기
            
            # 진행상황 출력 (100개마다)
            if idx % 100 == 0:
                print(f"처리 중: {idx}/{len(df)}")
        else:
            locations.append(None)
    
    return locations

# %%
# 위치 정보 조회 실행
test['org_locationDetail'] = get_all_locations(test, MAPBOX_ACCESS_TOKEN)

# 결과 확인
print("\n위치 정보 조회 결과 샘플:")
print(test[['orgLatLon', 'org_latitude', 'org_longitude', 'org_locationDetail']].head())
# Out:
# 처리 중: 0/6880
# 처리 중: 100/6880
# 처리 중: 200/6880
# 처리 중: 300/6880
# 처리 중: 400/6880
# 처리 중: 500/6880
# 처리 중: 600/6880
# 처리 중: 700/6880
# 처리 중: 800/6880
# 처리 중: 900/6880
# 처리 중: 1000/6880
# 처리 중: 1100/6880
# 처리 중: 1200/6880
# 처리 중: 1300/6880
# 처리 중: 1400/6880
# 처리 중: 1500/6880
# 처리 중: 1600/6880
# 처리 중: 1700/6880
# 처리 중: 1800/6880
# 처리 중: 1900/6880
# 처리 중: 2000/6880
# 처리 중: 2100/6880
# 처리 중: 2200/6880
# 처리 중: 2300/6880
# 처리 중: 2400/6880
# 처리 중: 2500/6880
# 처리 중: 2600/6880
# 처리 중: 2700/6880
# 처리 중: 2800/6880
# 처리 중: 2900/6880
# 처리 중: 3000/6880
# 처리 중: 3100/6880
# 처리 중: 3200/6880
# 처리 중: 3300/6880
# 처리 중: 3400/6880
# 처리 중: 3500/6880
# 처리 중: 3600/6880
# 처리 중: 3700/6880
# 처리 중: 3800/6880
# 처리 중: 3900/6880
# 처리 중: 4000/6880
# 처리 중: 4100/6880
# 처리 중: 4200/6880
# 처리 중: 4300/6880
# 처리 중: 4400/6880
# 처리 중: 4500/6880
# 처리 중: 4600/6880
# 처리 중: 4700/6880
# 처리 중: 4800/6880
# 처리 중: 4900/6880
# 처리 중: 5000/6880
# 처리 중: 5100/6880
# 처리 중: 5200/6880
# 처리 중: 5300/6880
# 처리 중: 5400/6880
# 처리 중: 5500/6880
# 처리 중: 5600/6880
# 처리 중: 5700/6880
# 처리 중: 5800/6880
# 처리 중: 5900/6880
# 처리 중: 6000/6880
# 처리 중: 6100/6880
# 처리 중: 6200/6880
# 처리 중: 6300/6880
# 처리 중: 6400/6880
# 처리 중: 6500/6880
# 처리 중: 6600/6880
# 처리 중: 6700/6880
# 처리 중: 6800/6880
#
# 위치 정보 조회 결과 샘플:
#          orgLatLon  org_latitude  org_longitude  \
# 0  13.1550,80.1960        13.155         80.196
# 1  12.8390,79.9540        12.839         79.954
# 2  11.8710,79.7390        11.871         79.739
# 3  12.8390,79.9540        12.839         79.954
# 4  11.8720,79.6320        11.872         79.632
#
#                                   org_locationDetail
# 0  Vanagaram - Ambathur - Puzhal Road, 수라페트, 6000...
# 1  Singaperumalkoil - Sriperumbudur - Thiruvallur...
# 2  Korkadu Erikarai Road, 605110, Bahour, Puduche...
# 3  Singaperumalkoil - Sriperumbudur - Thiruvallur...
# 4        Rc-21, 605106, Bahour, Puducherry, 푸두체리, 인도

# %%
# 위치 정보 조회 실행
test['des_locationDetail'] = get_all_locations(test, MAPBOX_ACCESS_TOKEN)

# 결과 확인
print("\n위치 정보 조회 결과 샘플:")
print(test[['desLatLon', 'des_latitude', 'des_longitude', 'des_locationDetail']].head())
# Out:
# 처리 중: 0/6880
# 처리 중: 100/6880
# 처리 중: 200/6880
# 처리 중: 300/6880
# 처리 중: 400/6880
# 처리 중: 500/6880
# 처리 중: 600/6880
# 처리 중: 700/6880
# 처리 중: 800/6880
# 처리 중: 900/6880
# 처리 중: 1000/6880
# 처리 중: 1100/6880
# 처리 중: 1200/6880
# 처리 중: 1300/6880
# 처리 중: 1400/6880
# 처리 중: 1500/6880
# 처리 중: 1600/6880
# 처리 중: 1700/6880
# 처리 중: 1800/6880
# 처리 중: 1900/6880
# 처리 중: 2000/6880
# 처리 중: 2100/6880
# 처리 중: 2200/6880
# 처리 중: 2300/6880
# 처리 중: 2400/6880
# 처리 중: 2500/6880
# 처리 중: 2600/6880
# 처리 중: 2700/6880
# 처리 중: 2800/6880
# 처리 중: 2900/6880
# 처리 중: 3000/6880
# 처리 중: 3100/6880
# 처리 중: 3200/6880
# 처리 중: 3300/6880
# 처리 중: 3400/6880
# 처리 중: 3500/6880
# 처리 중: 3600/6880
# 처리 중: 3700/6880
# 처리 중: 3800/6880
# 처리 중: 3900/6880
# 처리 중: 4000/6880
# 처리 중: 4100/6880
# 처리 중: 4200/6880
# 처리 중: 4300/6880
# 처리 중: 4400/6880
# 처리 중: 4500/6880
# 처리 중: 4600/6880
# 처리 중: 4700/6880
# 처리 중: 4800/6880
# 처리 중: 4900/6880
# 처리 중: 5000/6880
# 처리 중: 5100/6880
# 처리 중: 5200/6880
# 처리 중: 5300/6880
# 처리 중: 5400/6880
# 처리 중: 5500/6880
# 처리 중: 5600/6880
# 처리 중: 5700/6880
# 처리 중: 5800/6880
# 처리 중: 5900/6880
# 처리 중: 6000/6880
# 처리 중: 6100/6880
# 처리 중: 6200/6880
# 처리 중: 6300/6880
# 처리 중: 6400/6880
# 처리 중: 6500/6880
# 처리 중: 6600/6880
# 처리 중: 6700/6880
# 처리 중: 6800/6880
#
# 위치 정보 조회 결과 샘플:
#          desLatLon  des_latitude  des_longitude  \
# 0  12.7400,77.8200        12.740         77.820
# 1  12.8390,79.9540        12.839         79.954
# 2  11.8710,79.7390        11.871         79.739
# 3  12.8390,79.9540        12.839         79.954
# 4  11.8720,79.6320        11.872         79.632
#
#                                   des_locationDetail
# 0  Vanagaram - Ambathur - Puzhal Road, 수라페트, 6000...
# 1  Singaperumalkoil - Sriperumbudur - Thiruvallur...
# 2  Korkadu Erikarai Road, 605110, Bahour, Puduche...
# 3  Singaperumalkoil - Sriperumbudur - Thiruvallur...
# 4        Rc-21, 605106, Bahour, Puducherry, 푸두체리, 인도

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gpsprovider                  5927 non-null   object
#  1   bookingid                    6880 non-null   object
#  2   bookingidDate                6880 non-null   datetime64[ns]
#  3   vehicleNo                    6880 non-null   object
#  4   originLocation               6880 non-null   object
#  5   destinationLocation          6880 non-null   object
#  6   orgLatLon                    6880 non-null   object
#  7   desLatLon                    6880 non-null   object
#  8   plannedEta                   6880 non-null   object
#  9   currentLocation              5916 non-null   object
#  10  destinationlocation          6880 non-null   object
#  11  actualEta                    6843 non-null   object
#  12  ontime                       2548 non-null   object
#  13  delay                        4342 non-null   object
#  14  tripStartDate                6880 non-null   datetime64[ns]
#  15  tripEndDate                  6686 non-null   datetime64[ns]
#  16  tripDuration                 6686 non-null   float64
#  17  transportationDistanceInKm   6168 non-null   float64
#  18  minimumKmsToBeCoveredInADay  2820 non-null   float64
#  19  customerid                   6880 non-null   object
#  20  customernamecode             6880 non-null   object
#  21  uniqueKey                    6880 non-null   object
#  22  delivery_status              6880 non-null   object
#  23  delivery_status_code         6880 non-null   int64
#  24  org_latitude                 6880 non-null   float64
#  25  org_longitude                6880 non-null   float64
#  26  org_locationDetail           6880 non-null   object
#  27  des_latitude                 6880 non-null   float64
#  28  des_longitude                6880 non-null   float64
#  29  des_locationDetail           6880 non-null   object
# dtypes: datetime64[ns](3), float64(7), int64(1), object(19)
# memory usage: 1.6+ MB

# %%
col_lst=['gpsprovider', 'bookingid', 'bookingidDate', 'vehicleNo', 'originLocation', 'destinationLocation', 'orgLatLon', 'desLatLon'
         , 'org_latitude', 'org_longitude', 'org_locationDetail', 'des_latitude', 'des_longitude', 'des_locationDetail'
         , 'plannedEta', 'currentLocation', 'destinationlocation', 'actualEta', 'tripStartDate', 'tripEndDate', 'tripDuration'
         , 'transportationDistanceInKm', 'minimumKmsToBeCoveredInADay', 'ontime', 'delay']

test2 = test[col_lst].copy()

# %%
test2.head(2)
# Out:
#      gpsprovider           bookingid           bookingidDate   vehicleNo  \
# 0  CONSENT TRACK  MVCV0000927/082021 2020-08-17 14:59:01.000    KA590408
# 1        VAMOSYS  VCV00014271/082021 2020-08-27 16:22:22.827  TN30BC5917
#
#                                       originLocation  \
# 0               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
#
#                                  destinationLocation        orgLatLon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
#
#          desLatLon  org_latitude  org_longitude  ...  \
# 0  12.7400,77.8200        13.155         80.196  ...
# 1  12.8390,79.9540        12.839         79.954  ...
#
#                                      currentLocation  \
# 0  Vaniyambadi Rd, Valayambattu, Tamil Nadu 63575...
# 1  Unnamed Road, Oragadam Industrial Corridor, Va...
#
#                                  destinationlocation  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
#
#                     actualEta       tripStartDate tripEndDate tripDuration  \
# 0  2020-08-28 14:38:04.447000 2020-08-17 14:59:01         NaT          NaN
# 1  2020-08-28 12:46:17.007000 2020-08-27 16:21:52         NaT          NaN
#
#   transportationDistanceInKm minimumKmsToBeCoveredInADay ontime delay
# 0                      320.0                         NaN    NaN     R
# 1                      103.0                         NaN      G   NaN
#
# [2 rows x 25 columns]

# %% [markdown]
# #### 3.2 org_lonlat과 des_lonlat 컬럼 간의 거리 계산

# %%
def get_route_info(org_lon, org_lat, des_lon, des_lat, access_token):
    """
    MapBox Directions API를 사용하여 두 지점 간의 경로 정보를 조회
    
    Parameters:
    - org_lon, org_lat: 출발지 좌표
    - des_lon, des_lat: 도착지 좌표
    - access_token: MapBox API 토큰
    
    Returns:
    - 거리(km), 예상 소요시간(분), 경로 좌표 목록
    """
    base_url = "https://api.mapbox.com/directions/v5/mapbox/driving"
    
    try:
        # API 엔드포인트 구성
        coordinates = f"{org_lon},{org_lat};{des_lon},{des_lat}"
        url = f"{base_url}/{coordinates}"
        
        # 파라미터 설정
        params = {
            'access_token': access_token,
            'geometries': 'geojson',
            'overview': 'full',
            'steps': 'true'
        }
        
        # API 요청
        response = requests.get(url, params=params)
        data = response.json()
        
        if data.get('routes'):
            route = data['routes'][0]
            distance_km = round(route['distance'] / 1000, 2)  # 미터를 킬로미터로 변환
            duration_min = round(route['duration'] / 60, 2)   # 초를 분으로 변환
            geometry = route['geometry']['coordinates']       # 경로 좌표
            
            return {
                'distance_km': distance_km,
                'duration_min': duration_min,
                'geometry': geometry
            }
        return None
    
    except Exception as e:
        print(f"에러 발생: {e}")
        return None

# %%
def calculate_routes_batch(df, access_token, batch_size=100):
    """
    데이터프레임의 모든 출발지-도착지 쌍에 대한 경로 정보를 배치로 처리
    
    Parameters:
    - df: 데이터프레임
    - access_token: MapBox API 토큰
    - batch_size: 한 번에 처리할 데이터 수
    """
    distances = []
    durations = []
    geometries = []
    
    total_rows = len(df)
    
    for i in range(0, total_rows, batch_size):
        batch = df.iloc[i:min(i+batch_size, total_rows)]
        
        print(f"배치 처리 중: {i+1}-{min(i+batch_size, total_rows)} / {total_rows}")
        
        for _, row in batch.iterrows():
            if pd.notna(row['org_longitude']) and pd.notna(row['des_longitude']):
                route_info = get_route_info(
                    row['org_longitude'], row['org_latitude'],
                    row['des_longitude'], row['des_latitude'],
                    access_token
                )
                
                if route_info:
                    distances.append(route_info['distance_km'])
                    durations.append(route_info['duration_min'])
                    geometries.append(route_info['geometry'])
                else:
                    distances.append(None)
                    durations.append(None)
                    geometries.append(None)
            else:
                distances.append(None)
                durations.append(None)
                geometries.append(None)
            
            time.sleep(0.1)  # API 호출 제한 준수
    
    return distances, durations, geometries

# %%
# 경로 정보 계산 실행
distances, durations, geometries = calculate_routes_batch(test2, MAPBOX_ACCESS_TOKEN)

# 결과를 데이터프레임에 추가
test2['calculated_distance_km'] = distances
test2['estimated_duration_min'] = durations
test2['route_geometry'] = geometries

# 결과 확인
print("\n경로 계산 결과 샘플:")
print(test2[['orgLatLon', 'desLatLon', 'calculated_distance_km', 'estimated_duration_min']].head())

# 실제 운송 거리와 계산된 거리 비교 (선택적)
if 'transportationDistanceInKm' in test2.columns:
    test2['distance_difference'] = abs(test2['transportationDistanceInKm'] - test2['calculated_distance_km'])
    
    print("\n실제 거리와 계산된 거리 차이 통계:")
    print(test2['distance_difference'].describe())
# Out:
# 배치 처리 중: 1-100 / 6880
# 배치 처리 중: 101-200 / 6880
# 배치 처리 중: 201-300 / 6880
# 배치 처리 중: 301-400 / 6880
# 배치 처리 중: 401-500 / 6880
# 배치 처리 중: 501-600 / 6880
# 배치 처리 중: 601-700 / 6880
# 배치 처리 중: 701-800 / 6880
# 배치 처리 중: 801-900 / 6880
# 배치 처리 중: 901-1000 / 6880
# 배치 처리 중: 1001-1100 / 6880
# 배치 처리 중: 1101-1200 / 6880
# 배치 처리 중: 1201-1300 / 6880
# 배치 처리 중: 1301-1400 / 6880
# 배치 처리 중: 1401-1500 / 6880
# 배치 처리 중: 1501-1600 / 6880
# 배치 처리 중: 1601-1700 / 6880
# 배치 처리 중: 1701-1800 / 6880
# 배치 처리 중: 1801-1900 / 6880
# 배치 처리 중: 1901-2000 / 6880
# 배치 처리 중: 2001-2100 / 6880
# 배치 처리 중: 2101-2200 / 6880
# 배치 처리 중: 2201-2300 / 6880
# 배치 처리 중: 2301-2400 / 6880
# 배치 처리 중: 2401-2500 / 6880
# 배치 처리 중: 2501-2600 / 6880
# 배치 처리 중: 2601-2700 / 6880
# 배치 처리 중: 2701-2800 / 6880
# 배치 처리 중: 2801-2900 / 6880
# 배치 처리 중: 2901-3000 / 6880
# 배치 처리 중: 3001-3100 / 6880
# 배치 처리 중: 3101-3200 / 6880
# 배치 처리 중: 3201-3300 / 6880
# 배치 처리 중: 3301-3400 / 6880
# 배치 처리 중: 3401-3500 / 6880
# 배치 처리 중: 3501-3600 / 6880
# 배치 처리 중: 3601-3700 / 6880
# 배치 처리 중: 3701-3800 / 6880
# 배치 처리 중: 3801-3900 / 6880
# 배치 처리 중: 3901-4000 / 6880
# 배치 처리 중: 4001-4100 / 6880
# 배치 처리 중: 4101-4200 / 6880
# 배치 처리 중: 4201-4300 / 6880
# 배치 처리 중: 4301-4400 / 6880
# 배치 처리 중: 4401-4500 / 6880
# 배치 처리 중: 4501-4600 / 6880
# 배치 처리 중: 4601-4700 / 6880
# 배치 처리 중: 4701-4800 / 6880
# 배치 처리 중: 4801-4900 / 6880
# 배치 처리 중: 4901-5000 / 6880
# 배치 처리 중: 5001-5100 / 6880
# 배치 처리 중: 5101-5200 / 6880
# 배치 처리 중: 5201-5300 / 6880
# 배치 처리 중: 5301-5400 / 6880
# 배치 처리 중: 5401-5500 / 6880
# 배치 처리 중: 5501-5600 / 6880
# 배치 처리 중: 5601-5700 / 6880
# 배치 처리 중: 5701-5800 / 6880
# 배치 처리 중: 5801-5900 / 6880
# 배치 처리 중: 5901-6000 / 6880
# 배치 처리 중: 6001-6100 / 6880
# 배치 처리 중: 6101-6200 / 6880
# 배치 처리 중: 6201-6300 / 6880
# 배치 처리 중: 6301-6400 / 6880
# 배치 처리 중: 6401-6500 / 6880
# 배치 처리 중: 6501-6600 / 6880
# 배치 처리 중: 6601-6700 / 6880
# 배치 처리 중: 6701-6800 / 6880
# 배치 처리 중: 6801-6880 / 6880
#
# 경로 계산 결과 샘플:
#          orgLatLon        desLatLon  calculated_distance_km  \
# 0  13.1550,80.1960  12.7400,77.8200                  324.52
# 1  12.8390,79.9540  12.8390,79.9540                    0.00
# 2  11.8710,79.7390  11.8710,79.7390                    0.00
# 3  12.8390,79.9540  12.8390,79.9540                    0.00
# 4  11.8720,79.6320  11.8720,79.6320                    0.00
#
#    estimated_duration_min
# 0                  349.38
# 1                    0.00
# 2                    0.00
# 3                    0.00
# 4                    0.00
#
# 실제 거리와 계산된 거리 차이 통계:
# count    6168.000000
# mean      265.942910
# std       454.228183
# min         0.000000
# 25%        13.950000
# 50%        56.680000
# 75%       269.257500
# max      2165.530000
# Name: distance_difference, dtype: float64

# %%
test2.columns
# Out:
# Index(['gpsprovider', 'bookingid', 'bookingidDate', 'vehicleNo',
#        'originLocation', 'destinationLocation', 'orgLatLon', 'desLatLon',
#        'org_latitude', 'org_longitude', 'org_locationDetail', 'des_latitude',
#        'des_longitude', 'des_locationDetail', 'plannedEta', 'currentLocation',
#        'destinationlocation', 'actualEta', 'tripStartDate', 'tripEndDate',
#        'tripDuration', 'transportationDistanceInKm',
#        'minimumKmsToBeCoveredInADay', 'ontime', 'delay',
#        'calculated_distance_km', 'estimated_duration_min', 'route_geometry',
#        'distance_difference'],
#       dtype='object')

# %%
col_lst2=['gpsprovider', 'bookingid', 'bookingidDate', 'vehicleNo', 'originLocation', 'destinationLocation', 'orgLatLon', 'desLatLon'
         , 'org_latitude', 'org_longitude', 'org_locationDetail', 'des_latitude', 'des_longitude', 'des_locationDetail'
         , 'plannedEta', 'currentLocation', 'destinationlocation', 'actualEta', 'tripStartDate', 'tripEndDate', 'tripDuration'
         , 'transportationDistanceInKm', 'minimumKmsToBeCoveredInADay'
         , 'calculated_distance_km', 'estimated_duration_min'
        #  , 'route_geometry'
         , 'distance_difference'
         , 'ontime', 'delay']

test3 = test2[col_lst2].copy()

# %%
test3.to_excel('winter_internship_prj_250122_v2.0.xlsx', index=False)

# %%
# 1. 메모리 사용량 확인
def get_size(df):
    """
    데이터프레임의 메모리 사용량을 확인하는 함수
    """
    # 메모리 사용량을 MB 단위로 변환
    memory_usage = df.memory_usage(deep=True).sum() / 1024 / 1024
    print(f"데이터프레임 메모리 사용량: {memory_usage:.2f} MB")
    
    # 컬럼별 메모리 사용량
    print("\n컬럼별 메모리 사용량:")
    for col in df.columns:
        col_memory = df[col].memory_usage(deep=True) / 1024 / 1024
        print(f"{col}: {col_memory:.2f} MB")

# 메모리 사용량 확인
get_size(test3)
# Out:
# 데이터프레임 메모리 사용량: 9.72 MB
#
# 컬럼별 메모리 사용량:
# gpsprovider: 0.41 MB
# bookingid: 0.46 MB
# bookingidDate: 0.05 MB
# vehicleNo: 0.44 MB
# originLocation: 0.59 MB
# destinationLocation: 0.60 MB
# orgLatLon: 0.54 MB
# desLatLon: 0.52 MB
# org_latitude: 0.05 MB
# org_longitude: 0.05 MB
# org_locationDetail: 1.41 MB
# des_latitude: 0.05 MB
# des_longitude: 0.05 MB
# des_locationDetail: 1.41 MB
# plannedEta: 0.37 MB
# currentLocation: 0.73 MB
# destinationlocation: 0.60 MB
# actualEta: 0.37 MB
# tripStartDate: 0.05 MB
# tripEndDate: 0.05 MB
# tripDuration: 0.05 MB
# transportationDistanceInKm: 0.05 MB
# minimumKmsToBeCoveredInADay: 0.05 MB
# calculated_distance_km: 0.05 MB
# estimated_duration_min: 0.05 MB
# distance_difference: 0.05 MB
# ontime: 0.27 MB
# delay: 0.32 MB

# %% [markdown]
# ### Current Location, Destination Location 거리 추출

# %% [markdown]
# #### data load (데이터 불러오기)

# %%
# 엑셀 파일 경로 설정
file_path = "/Users/howsang/Documents/002.Study/001.project/001.internship/p_truck_delivery/data/delivery_data_sample_250127_v2.0.xlsx"  # 파일명을 실제 파일 이름으로 변경하세요.

# Excel 파일 읽기 (engine='openpyxl' 명시)
excel_data = pd.ExcelFile(file_path, engine='openpyxl')

# 모든 시트 이름 확인 (선택적으로 확인 가능)
print("Available sheets:", excel_data.sheet_names)

# 두 번째 시트의 데이터 읽기 (시트 인덱스는 0부터 시작)
df = pd.read_excel(file_path, sheet_name=1, engine='openpyxl', usecols='B:AC')  # sheet_name=1은 두 번째 시트를 의미

# 데이터프레임 확인
print(df)
# Out:
# Available sheets: ['info', 'data']
#         gpsprovider           bookingid           bookingidDate   vehicleNo  \
# 0     CONSENT TRACK  MVCV0000927/082021 2020-08-17 14:59:01.000    KA590408
# 1           VAMOSYS  VCV00014271/082021 2020-08-27 16:22:22.827  TN30BC5917
# 2     CONSENT TRACK  VCV00014382/082021 2020-08-27 17:59:25.000  TN22AR2748
# 3           VAMOSYS  VCV00014743/082021 2020-08-28 00:48:24.503  TN28AQ0781
# 4           VAMOSYS  VCV00014744/082021 2020-08-28 01:23:19.243   TN68F1722
# ...             ...                 ...                     ...         ...
# 6875          JTECH        WDSBKTP42751 2019-03-27 17:25:33.000    KA219502
# 6876          JTECH        WDSBKTP43203 2019-03-31 15:02:34.000  KA01AE9163
# 6877          JTECH        WDSBKTP43021 2019-03-29 18:56:26.000  KA01AE9163
# 6878          JTECH        WDSBKTP42685 2019-03-27 08:29:45.000   KA21A3643
# 6879          JTECH        WDSBKTP42858 2019-03-28 17:55:17.000   KA51D1317
#
#                                          originLocation  \
# 0                  TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875             Ramamurthy Nagar, Bangalore, Karnataka
# 6876             Ramamurthy Nagar, Bangalore, Karnataka
# 6877               Mugabala, Bangalore Rural, Karnataka
# 6878               Mugabala, Bangalore Rural, Karnataka
# 6879               Mugabala, Bangalore Rural, Karnataka
#
#                                     destinationLocation  \
# 0          ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875            Sahakaranagar P.O, Bangalore, Karnataka
# 6876  Bangalore International Airport, Bangalore, Ka...
# 6877                       Anekal, Bangalore, Karnataka
# 6878                       Anekal, Bangalore, Karnataka
# 6879                       Anekal, Bangalore, Karnataka
#
#                                   orgLatLon  \
# 0                           13.1550,80.1960
# 1                           12.8390,79.9540
# 2                           11.8710,79.7390
# 3                           12.8390,79.9540
# 4                           11.8720,79.6320
# ...                                     ...
# 6875  13.007503209603689,77.665098855934886
# 6876  13.007503209603689,77.665098855934886
# 6877  16.560192249175344,80.792293091599547
# 6878  16.560192249175344,80.792293091599547
# 6879  16.560192249175344,80.792293091599547
#
#                                   desLatLon  org_latitude  org_longitude  ...  \
# 0                           12.7400,77.8200     13.155000      80.196000  ...
# 1                           12.8390,79.9540     12.839000      79.954000  ...
# 2                           11.8710,79.7390     11.871000      79.739000  ...
# 3                           12.8390,79.9540     12.839000      79.954000  ...
# 4                           11.8720,79.6320     11.872000      79.632000  ...
# ...                                     ...           ...            ...  ...
# 6875  13.068901840235711,77.590655738806618     13.007503      77.665099  ...
# 6876  13.196312912801169,77.708156925688726     13.007503      77.665099  ...
# 6877                    12.722686,77.676518     16.560192      80.792293  ...
# 6878  12.896896847817695,77.712223056874862     16.560192      80.792293  ...
# 6879  13.199089183304451,77.708554234959038     16.560192      80.792293  ...
#
#             tripStartDate          tripEndDate  tripDuration  \
# 0     2020-08-17 14:59:01                  NaN           NaN
# 1     2020-08-27 16:21:52                  NaN           NaN
# 2     2020-08-27 17:57:04                  NaN           NaN
# 3     2020-08-28 00:47:45                  NaN           NaN
# 4     2020-08-28 01:13:48                  NaN           NaN
# ...                   ...                  ...           ...
# 6875  2019-03-27 18:00:00  2019-03-27 17:46:00     -0.233333
# 6876  2019-03-31 17:30:00  2019-03-31 19:51:00      2.350000
# 6877  2019-03-29 20:44:00  2019-03-30 00:53:00      4.150000
# 6878  2019-03-27 15:29:00  2019-03-27 16:35:00      1.100000
# 6879  2019-03-28 20:26:00  2019-03-28 23:41:00      3.250000
#
#      transportationDistanceInKm calculated_distance_km estimated_duration_min  \
# 0                         320.0                 324.52                 349.38
# 1                         103.0                   0.00                   0.00
# 2                         300.0                   0.00                   0.00
# 3                          61.0                   0.00                   0.00
# 4                         240.0                   0.00                   0.00
# ...                         ...                    ...                    ...
# 6875                       12.0                  13.65                  35.81
# 6876                       31.0                  36.29                  63.08
# 6877                       49.0                 718.55                 765.19
# 6878                       49.0                 706.22                 729.64
# 6879                       49.0                 663.58                 704.23
#
#      distance_difference ontime delay  \
# 0                   4.52    NaN     R
# 1                 103.00      G   NaN
# 2                 300.00      G   NaN
# 3                  61.00      G   NaN
# 4                 240.00      G   NaN
# ...                  ...    ...   ...
# 6875                1.65      G   NaN
# 6876                5.29      G   NaN
# 6877              669.55      G   NaN
# 6878              657.22    NaN     R
# 6879              614.58      G   NaN
#
#                                            hotKey
# 0     MVCV0000927/082021_ALLEXCHE45_CONSENT TRACK
# 1           VCV00014271/082021_DMREXCHEUX_VAMOSYS
# 2     VCV00014382/082021_LUTGCCHE06_CONSENT TRACK
# 3           VCV00014743/082021_DMREXCHEUX_VAMOSYS
# 4           VCV00014744/082021_LUTGCCHE06_VAMOSYS
# ...                                           ...
# 6875                WDSBKTP42751_LTLEXMUM40_JTECH
# 6876                WDSBKTP43203_LTLEXMUM40_JTECH
# 6877                WDSBKTP43021_LTLEXMUM40_JTECH
# 6878                WDSBKTP42685_LTLEXMUM40_JTECH
# 6879                WDSBKTP42858_LTLEXMUM40_JTECH
#
# [6880 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gpsprovider                 5927 non-null   object
#  1   bookingid                   6880 non-null   object
#  2   bookingidDate               6880 non-null   datetime64[ns]
#  3   vehicleNo                   6880 non-null   object
#  4   originLocation              6880 non-null   object
#  5   destinationLocation         6880 non-null   object
#  6   orgLatLon                   6880 non-null   object
#  7   desLatLon                   6880 non-null   object
#  8   org_latitude                6880 non-null   float64
#  9   org_longitude               6880 non-null   float64
#  10  org_locationDetail          6880 non-null   object
#  11  des_latitude                6880 non-null   float64
#  12  des_longitude               6880 non-null   float64
#  13  des_locationDetail          6880 non-null   object
#  14  plannedEta                  6880 non-null   object
#  15  currentLocation             5916 non-null   object
#  16  destinationlocation         6880 non-null   object
#  17  actualEta                   6843 non-null   object
#  18  tripStartDate               6880 non-null   object
#  19  tripEndDate                 6686 non-null   object
#  20  tripDuration                6686 non-null   float64
#  21  transportationDistanceInKm  6168 non-null   float64
#  22  calculated_distance_km      6880 non-null   float64
#  23  estimated_duration_min      6880 non-null   float64
#  24  distance_difference         6168 non-null   float64
#  25  ontime                      2548 non-null   object
#  26  delay                       4342 non-null   object
#  27  hotKey                      6880 non-null   object
# dtypes: datetime64[ns](1), float64(9), object(18)
# memory usage: 1.5+ MB

# %%
key=""
g = geocoder.mapbox('Vaniyambadi Rd, Valayambattu, Tamil Nadu 635752, India', key=key)
result=g.json

# %%
result
# Out:
# {'address': 'Vaniyambadi, Tamil Nadu, India',
#  'bbox': {'northeast': [12.774211, 78.832381],
#   'southwest': [12.447587, 78.489152]},
#  'confidence': 1,
#  'country': 'India',
#  'lat': 12.678486,
#  'lng': 78.62049,
#  'ok': True,
#  'quality': 0.670635,
#  'raw': {'id': 'place.46671979',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 0.670635,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBc2dvYXc',
#    'wikidata': 'Q282212'},
#   'text': 'Vaniyambadi',
#   'place_name': 'Vaniyambadi, Tamil Nadu, India',
#   'bbox': [78.489152, 12.447587, 78.832381, 12.774211],
#   'center': [78.62049, 12.678486],
#   'geometry': {'type': 'Point', 'coordinates': [78.62049, 12.678486]},
#   'context': [{'id': 'district.5588587',
#     'mapbox_id': 'dXJuOm1ieHBsYzpWVVpy',
#     'wikidata': 'Q66659621',
#     'text': 'Tirupathur'},
#    {'id': 'region.173163',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBcVJy',
#     'wikidata': 'Q1445',
#     'short_code': 'IN-TN',
#     'text': 'Tamil Nadu'},
#    {'id': 'country.8811',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJbXM',
#     'wikidata': 'Q668',
#     'short_code': 'in',
#     'text': 'India'}],
#   'district': 'Tirupathur',
#   'region': 'Tamil Nadu',
#   'country': 'India'},
#  'state': 'Tamil Nadu',
#  'status': 'OK'}

# %%
result.get('raw')
# Out:
# {'id': 'place.46671979',
#  'type': 'Feature',
#  'place_type': ['place'],
#  'relevance': 0.670635,
#  'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBc2dvYXc', 'wikidata': 'Q282212'},
#  'text': 'Vaniyambadi',
#  'place_name': 'Vaniyambadi, Tamil Nadu, India',
#  'bbox': [78.489152, 12.447587, 78.832381, 12.774211],
#  'center': [78.62049, 12.678486],
#  'geometry': {'type': 'Point', 'coordinates': [78.62049, 12.678486]},
#  'context': [{'id': 'district.5588587',
#    'mapbox_id': 'dXJuOm1ieHBsYzpWVVpy',
#    'wikidata': 'Q66659621',
#    'text': 'Tirupathur'},
#   {'id': 'region.173163',
#    'mapbox_id': 'dXJuOm1ieHBsYzpBcVJy',
#    'wikidata': 'Q1445',
#    'short_code': 'IN-TN',
#    'text': 'Tamil Nadu'},
#   {'id': 'country.8811',
#    'mapbox_id': 'dXJuOm1ieHBsYzpJbXM',
#    'wikidata': 'Q668',
#    'short_code': 'in',
#    'text': 'India'}],
#  'district': 'Tirupathur',
#  'region': 'Tamil Nadu',
#  'country': 'India'}

# %%
def curr_locations(df, key):
    """
    데이터프레임의 주소들에 대해 위도와 경도를 추출
    """
    # 데이터프레임 길이만큼 None으로 초기화
    df_cur_lat = [None] * len(df)
    df_cur_lng = [None] * len(df)
    df_cur_district = [None] * len(df)
    df_cur_region = [None] * len(df)
    df_cur_country = [None] * len(df)
    
    api_key = key
    
    for idx, row in tqdm(df.iterrows()):
        if pd.notna(row['currentLocation']):
            try:
                # geocoder로 위치 정보 요청
                g = geocoder.mapbox(row['currentLocation'], key=api_key)
                result = g.json
        
                # status가 'OK'인 경우에만 좌표 저장
                if result and result.get('status') == 'OK':
                    df_cur_lat[idx] = result.get('lat')
                    df_cur_lng[idx] = result.get('lng')
                    df_cur_district[idx] = result.get('raw', {}).get('district')
                    df_cur_region[idx] = result.get('raw', {}).get('region')
                    df_cur_country[idx] = result.get('raw', {}).get('country')
                
                # API 요청 제한 준수를 위한 대기
                time.sleep(0.1)
                
            except Exception as e:
                print(f"Error processing row {idx}: {e}")
                continue
                
    return pd.Series(df_cur_lat), pd.Series(df_cur_lng), pd.Series(df_cur_district), pd.Series(df_cur_region), pd.Series(df_cur_country)

# %%
# 함수 실행
df['current_latitude'], df['current_longitude'], df['current_district'], df['current_region'], df['current_country'] = curr_locations(df)

# 결과 확인
print("\n위치 정보 처리 결과:")
curr_columns = ['current_latitude', 'current_longitude', 'current_district', 'current_region', 'current_country']
print(df[curr_columns].head())
# Out:
# 24it [00:03,  7.08it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Part C, B200, IndoSpace Industrial Park Oragadam I Phase II Panrutti Village Oragadam - Wallajabad Road, Sriperumbudur Taluk, Kanchipuram District, Chennai, Sethupet, Tamil Nadu 631604, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Part%20C,%20B200,%20IndoSpace%20Industrial%20Park%20Oragadam%20I%20Phase%20II%20Panrutti%20Village%20Oragadam%20-%20Wallajabad%20Road,%20Sriperumbudur%20Taluk,%20Kanchipuram%20District,%20Chennai,%20Sethupet,%20Tamil%20Nadu%20631604,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 46it [00:07,  6.76it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 109it [00:16,  7.14it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/# 256/B Near Narayana Hrudayalaya Bommasandra, Besides Mahindra Showroom, Electronic City, Bengaluru, Karnataka 560099, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#%20256/B%20Near%20Narayana%20Hrudayalaya%20Bommasandra,%20Besides%20Mahindra%20Showroom,%20Electronic%20City,%20Bengaluru,%20Karnataka%20560099,%20India.json
# 198it [00:29,  6.99it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 224it [00:33,  7.11it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 234it [00:34,  6.99it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal Pet Pvt Ltd, G1-171&172, RIICO Industrial Area-2, Neemrana, Delhi - Ajmer Expy, Phase II, Neemrana, Rajasthan 301705, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal%20Pet%20Pvt%20Ltd,%20G1-171&172,%20RIICO%20Industrial%20Area-2,%20Neemrana,%20Delhi%20-%20Ajmer%20Expy,%20Phase%20II,%20Neemrana,%20Rajasthan%20301705,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 270it [00:39,  7.19it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 297it [00:43,  7.09it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Part C, B200, IndoSpace Industrial Park Oragadam I Phase II Panrutti Village Oragadam - Wallajabad Road, Sriperumbudur Taluk, Kanchipuram District, Chennai, Sethupet, Tamil Nadu 631604, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Part%20C,%20B200,%20IndoSpace%20Industrial%20Park%20Oragadam%20I%20Phase%20II%20Panrutti%20Village%20Oragadam%20-%20Wallajabad%20Road,%20Sriperumbudur%20Taluk,%20Kanchipuram%20District,%20Chennai,%20Sethupet,%20Tamil%20Nadu%20631604,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 309it [00:45,  6.99it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 360it [00:53,  7.03it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#6, Maruthi Nagar, SIPCOT Post, opp. Shivaranjani Hotel, Sunnambu Jeebi, Hosur, Tamil Nadu 635109, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#6,%20Maruthi%20Nagar,%20SIPCOT%20Post,%20opp.%20Shivaranjani%20Hotel,%20Sunnambu%20Jeebi,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json
# 412it [01:01,  7.21it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No1 ,Ashoka Nagar St, Ashoka Nagar, MMDA Colony, Arumbakkam Chennai, Tamil Nadu 600106, Call, Kanna Bala Nagar, Ashoka Nagar, Sri Sakthi Nagar, Arumbakkam, Chennai, Tamil Nadu 600106, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No1%20,Ashoka%20Nagar%20St,%20Ashoka%20Nagar,%20MMDA%20Colony,%20Arumbakkam%20Chennai,%20Tamil%20Nadu%20600106,%20Call,%20Kanna%20Bala%20Nagar,%20Ashoka%20Nagar,%20Sri%20Sakthi%20Nagar,%20Arumbakkam,%20Chennai,%20Tamil%20Nadu%20600106,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 449it [01:06,  6.77it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal Pet Pvt Ltd, G1-171&172, RIICO Industrial Area-2, Neemrana, Delhi - Ajmer Expy, Phase II, Neemrana, Rajasthan 301705, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal%20Pet%20Pvt%20Ltd,%20G1-171&172,%20RIICO%20Industrial%20Area-2,%20Neemrana,%20Delhi%20-%20Ajmer%20Expy,%20Phase%20II,%20Neemrana,%20Rajasthan%20301705,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 475it [01:10,  7.03it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 559it [01:22,  7.11it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 701it [01:43,  7.09it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 738it [01:48,  7.03it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal Pet Pvt Ltd, G1-171&172, RIICO Industrial Area-2, Neemrana, Delhi - Ajmer Expy, Phase II, Neemrana, Rajasthan 301705, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal%20Pet%20Pvt%20Ltd,%20G1-171&172,%20RIICO%20Industrial%20Area-2,%20Neemrana,%20Delhi%20-%20Ajmer%20Expy,%20Phase%20II,%20Neemrana,%20Rajasthan%20301705,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 800it [01:57,  7.16it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 848it [02:04,  7.08it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 892it [02:11,  7.15it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/?Pune - Pandharpur Rd, Maharashtra 415528, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?Pune%20-%20Pandharpur%20Rd,%20Maharashtra%20415528,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 971it [02:22,  6.35it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#4, mg nagar, near titan township, Hosur, Tamil Nadu 635110, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#4,%20mg%20nagar,%20near%20titan%20township,%20Hosur,%20Tamil%20Nadu%20635110,%20India.json
# 974it [02:23,  6.92it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal Pet Pvt Ltd, G1-171&172, RIICO Industrial Area-2, Neemrana, Delhi - Ajmer Expy, Phase II, Neemrana, Rajasthan 301705, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Frystal%20Pet%20Pvt%20Ltd,%20G1-171&172,%20RIICO%20Industrial%20Area-2,%20Neemrana,%20Delhi%20-%20Ajmer%20Expy,%20Phase%20II,%20Neemrana,%20Rajasthan%20301705,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1013it [02:28,  7.18it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Velammal Engineering College, Red Hills Road, Off Ambattur High Road, Post Surapet, Velammal Nagar, Ambattur, Chennai, Tamil Nadu, Surappattu, Chennai, Tamil Nadu 600066, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Velammal%20Engineering%20College,%20Red%20Hills%20Road,%20Off%20Ambattur%20High%20Road,%20Post%20Surapet,%20Velammal%20Nagar,%20Ambattur,%20Chennai,%20Tamil%20Nadu,%20Surappattu,%20Chennai,%20Tamil%20Nadu%20600066,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1054it [02:34,  7.23it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#NO 423 balaji nagar,bedrapalli,near sp plastech ,sipcot po, Bedrapalli, Hosur, Tamil Nadu 635126, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#NO%20423%20balaji%20nagar,bedrapalli,near%20sp%20plastech%20,sipcot%20po,%20Bedrapalli,%20Hosur,%20Tamil%20Nadu%20635126,%20India.json
# 1113it [02:43,  6.39it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Plot No: 9/3, MIG, NH-1, Thiruvalluvar Salai, Near St Joseph Hr Sec School, Maraimalai Nagar, Singaperumal Koil, Mahindra World City, Potheri, Urapakkam, Guduvancherry, Chengalpet, Peramanur, Maraimalai Nagar, Tamil Nadu 603204, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Plot%20No:%209/3,%20MIG,%20NH-1,%20Thiruvalluvar%20Salai,%20Near%20St%20Joseph%20Hr%20Sec%20School,%20Maraimalai%20Nagar,%20Singaperumal%20Koil,%20Mahindra%20World%20City,%20Potheri,%20Urapakkam,%20Guduvancherry,%20Chengalpet,%20Peramanur,%20Maraimalai%20Nagar,%20Tamil%20Nadu%20603204,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1261it [03:04,  7.13it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B, Vallalar Nagar,Opp to Ashok Leyland Unit 2, Sipcot Phase II Industrial Complex, Sipcot Ph 2, Hosur, Tamil Nadu 635109, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/No:42/2B,%20Vallalar%20Nagar,Opp%20to%20Ashok%20Leyland%20Unit%202,%20Sipcot%20Phase%20II%20Industrial%20Complex,%20Sipcot%20Ph%202,%20Hosur,%20Tamil%20Nadu%20635109,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1331it [03:15,  6.83it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Gestamp Sungwoo Stampings and Assemblies Pvt. Ltd, Plot No. B-12, SIPCOT Industrial Park, Phase II, Vengadu Village, Katrambakkam, Tamil Nadu 602105, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Gestamp%20Sungwoo%20Stampings%20and%20Assemblies%20Pvt.%20Ltd,%20Plot%20No.%20B-12,%20SIPCOT%20Industrial%20Park,%20Phase%20II,%20Vengadu%20Village,%20Katrambakkam,%20Tamil%20Nadu%20602105,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1519it [03:42,  7.83it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Pakhowal Bus Stop, ????? ???? ???, Pakhowal, Punjab 141108, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Pakhowal%20Bus%20Stop,%20?????%20????%20???,%20Pakhowal,%20Punjab%20141108,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1545it [03:46,  6.96it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Unnamed Road, ???, Harchandpura at Deoliya, Rajasthan 302037, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Unnamed%20Road,%20???,%20Harchandpura%20at%20Deoliya,%20Rajasthan%20302037,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1599it [03:53, 10.03it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#27, Annai Builders, Cuddalore, Pavendar Salai, Maraimalai Nagar, Tamil Nadu 603209, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#27,%20Annai%20Builders,%20Cuddalore,%20Pavendar%20Salai,%20Maraimalai%20Nagar,%20Tamil%20Nadu%20603209,%20India.json
# 1618it [03:55,  7.10it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Kamaluddin and son ( 9845991133 )#33,1st cross, Thanisandra Main Rd, near mamta clinic, sadiq layout, Ashwath Nagar, Sinthan Nagar, Bengaluru, Karnataka 560077, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Kamaluddin%20and%20son%20(%209845991133%20)?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#33,1st%20cross,%20Thanisandra%20Main%20Rd,%20near%20mamta%20clinic,%20sadiq%20layout,%20Ashwath%20Nagar,%20Sinthan%20Nagar,%20Bengaluru,%20Karnataka%20560077,%20India.json
# 1623it [03:56,  7.03it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Shop no-4, Siddheswar Heights, Near Ajwa Ratri Bazaar, NH No-8, Ajwa Road, Nehru Chacha Nagar, Sayaji Park Society, Vadodara, Gujarat 390019, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Shop%20no-4,%20Siddheswar%20Heights,%20Near%20Ajwa%20Ratri%20Bazaar,%20NH%20No-8,%20Ajwa%20Road,%20Nehru%20Chacha%20Nagar,%20Sayaji%20Park%20Society,%20Vadodara,%20Gujarat%20390019,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1788it [04:20,  6.98it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Mahadevappa HB Employment and training department #257, near vasavishanthi dhama, Alanahalli, Mysuru, Karnataka 570028, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Mahadevappa%20HB%20Employment%20and%20training%20department%20?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#257,%20near%20vasavishanthi%20dhama,%20Alanahalli,%20Mysuru,%20Karnataka%20570028,%20India.json
# 1795it [04:21,  6.61it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1796it [04:21,  3.67it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1797it [04:22,  3.89it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1798it [04:22,  3.96it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1799it [04:22,  4.05it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1800it [04:22,  4.18it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1801it [04:23,  3.42it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1802it [04:23,  3.69it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1803it [04:23,  3.93it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1804it [04:24,  3.10it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1831it [04:28,  7.13it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/?Pune - Pandharpur Rd, Maharashtra 415528, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?Pune%20-%20Pandharpur%20Rd,%20Maharashtra%20415528,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 1865it [04:32,  7.14it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#27, Annai Builders, Cuddalore, Pavendar Salai, Maraimalai Nagar, Tamil Nadu 603209, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#27,%20Annai%20Builders,%20Cuddalore,%20Pavendar%20Salai,%20Maraimalai%20Nagar,%20Tamil%20Nadu%20603209,%20India.json
# 2031it [04:56,  6.80it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Sagar SwitchGears Limited, 190 C&D Road-F, POR GIDC, Vadodara, Gujarat, India, F, Por GIDC Internal Road 1, GIDC Industrial Area, Gujarat 391243, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Sagar%20SwitchGears%20Limited,%20190%20C&D%20Road-F,%20POR%20GIDC,%20Vadodara,%20Gujarat,%20India,%20F,%20Por%20GIDC%20Internal%20Road%201,%20GIDC%20Industrial%20Area,%20Gujarat%20391243,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2089it [05:05,  7.11it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#9, KIADB Road, Near WIPRO, 1st Stage, Peenya, Bengaluru, Karnataka 560058, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#9,%20KIADB%20Road,%20Near%20WIPRO,%201st%20Stage,%20Peenya,%20Bengaluru,%20Karnataka%20560058,%20India.json
# 2102it [05:07,  6.46it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2111it [05:08,  6.59it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2127it [05:11,  6.59it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/GCI Castings (India) Private Limited, No. 66P, 67 & 68, 2nd Phase, Jigani Industrial Area, Bangalore, Bannerghatta Anekal Rd, Jigani, Karnataka 560105, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/GCI%20Castings%20(India)%20Private%20Limited,%20No.%2066P,%2067%20&%2068,%202nd%20Phase,%20Jigani%20Industrial%20Area,%20Bangalore,%20Bannerghatta%20Anekal%20Rd,%20Jigani,%20Karnataka%20560105,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2143it [05:14,  6.84it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2155it [05:16,  6.70it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2164it [05:17,  6.95it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2167it [05:18,  6.41it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey Environmental solution, #108, Mettu St, Madagadipet, Puducherry 605407, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey%20Environmental%20solution,%20?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#108,%20Mettu%20St,%20Madagadipet,%20Puducherry%20605407,%20India.json
# 2176it [05:19,  7.11it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2177it [05:19,  5.85it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2178it [05:19,  5.14it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2196it [05:22,  7.07it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2200it [05:23,  6.67it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2204it [05:23,  6.63it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey Environmental solution, #108, Mettu St, Madagadipet, Puducherry 605407, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey%20Environmental%20solution,%20?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#108,%20Mettu%20St,%20Madagadipet,%20Puducherry%20605407,%20India.json
# 2210it [05:24,  7.10it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2228it [05:27,  7.09it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2229it [05:27,  3.80it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey Environmental solution, #108, Mettu St, Madagadipet, Puducherry 605407, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Sanjey%20Environmental%20solution,%20?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#108,%20Mettu%20St,%20Madagadipet,%20Puducherry%20605407,%20India.json
# 2231it [05:28,  4.99it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2260it [05:32,  7.02it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2315it [05:40,  7.15it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/???? ???, Diara Sector, Bilaspur, Himachal Pradesh 174001, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/????%20???,%20Diara%20Sector,%20Bilaspur,%20Himachal%20Pradesh%20174001,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2369it [05:47,  6.93it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/9, Vegetable Market Yard, Near Ajwa Crossing, Near National Highway No. 8, Nehru Chacha Nagar, Sayaji Park Society, Vadodara, Gujarat 390019, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/9,%20Vegetable%20Market%20Yard,%20Near%20Ajwa%20Crossing,%20Near%20National%20Highway%20No.%208,%20Nehru%20Chacha%20Nagar,%20Sayaji%20Park%20Society,%20Vadodara,%20Gujarat%20390019,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2415it [05:54,  7.13it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2417it [05:55,  4.72it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2418it [05:55,  4.69it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2463it [06:01,  7.03it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2464it [06:02,  3.70it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2504it [06:08,  6.89it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/JCB Circle Sez Mahindra World City, ???, Harchandpura at Deoliya, Rajasthan 302037, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/JCB%20Circle%20Sez%20Mahindra%20World%20City,%20???,%20Harchandpura%20at%20Deoliya,%20Rajasthan%20302037,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2510it [06:08,  7.14it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2518it [06:10,  6.89it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2519it [06:10,  5.99it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2520it [06:10,  5.51it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2523it [06:11,  5.93it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Unnamed Road, ???, Teelawas, Rajasthan 302037, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Unnamed%20Road,%20???,%20Teelawas,%20Rajasthan%20302037,%20India.json&access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2524it [06:11,  6.17it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2578it [06:19,  7.14it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 2588it [06:20,  6.77it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Block no. 1 Survey no. 466,467,468,469, Plot no. 474, 485, Hosur - Thally Rd, near by Karnoor village, Tamil Nadu 635110, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Block%20no.%201%20Survey%20no.%20466,467,468,469,%20Plot%20no.%20474,%20485,%20Hosur%20-%20Thally%20Rd,%20near%20by%20Karnoor%20village,%20Tamil%20Nadu%20635110,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# ...
# 5563it [13:31,  4.31it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5569it [13:31,  6.46it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5570it [13:32,  5.78it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5571it [13:32,  5.23it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5572it [13:32,  4.87it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5575it [13:33,  4.88it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5576it [13:33,  4.79it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5578it [13:33,  5.26it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5583it [13:34,  6.54it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5584it [13:34,  5.76it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5587it [13:35,  5.26it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5588it [13:35,  4.73it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5589it [13:36,  4.70it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5590it [13:36,  4.54it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5591it [13:36,  4.45it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5592it [13:37,  3.44it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5593it [13:37,  3.74it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5594it [13:37,  3.96it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5620it [13:41,  7.16it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5627it [13:42,  6.60it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#43-1-41/1, Near gandhi bomma centre, kenal road,, Palakollu, Andhra Pradesh 534260, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#43-1-41/1,%20Near%20gandhi%20bomma%20centre,%20kenal%20road,,%20Palakollu,%20Andhra%20Pradesh%20534260,%20India.json
# 5632it [13:43,  6.28it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5633it [13:43,  5.23it/s]Status code 422 from https://api.mapbox.com/geocoding/v5/mapbox.places/Singh city hospital road LIG1, room no A56, Sector 3 Airoli Rd, CIDCO Colony, Kalamboli, Panvel, Navi Mumbai, Maharashtra 400708, India.json: ERROR - 422 Client Error: Unknown for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Singh%20city%20hospital%20road%20LIG1,%20room%20no%20A56,%20Sector%203%20Airoli%20Rd,%20CIDCO%20Colony,%20Kalamboli,%20Panvel,%20Navi%20Mumbai,%20Maharashtra%20400708,%20India.json?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg
# 5641it [13:44,  6.89it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/#43-1-41/1, Near gandhi bomma centre, kenal road,, Palakollu, Andhra Pradesh 534260, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#43-1-41/1,%20Near%20gandhi%20bomma%20centre,%20kenal%20road,,%20Palakollu,%20Andhra%20Pradesh%20534260,%20India.json
# 5828it [14:11,  7.13it/s]Status code 404 from https://api.mapbox.com/geocoding/v5/mapbox.places/Sampurna International -faber chimney hob oven store and peps mattress shope #695, 5th Main Road, OMBR Layout, Banaswadi Ring Road Near BABY Cart, chaya Hospital Road, Call to 8861688882, Bengaluru, Karnataka 560043, India.json: ERROR - 404 Client Error: Not Found for url: https://api.mapbox.com/geocoding/v5/mapbox.places/Sampurna%20International%20-faber%20chimney%20hob%20oven%20store%20and%20peps%20mattress%20shope%20?access_token=pk.eyJ1Ijoid2lsbG9nMjAyMSIsImEiOiJjbHpzMnh6aWgxZmkxMmtweWVhcXlxNHdmIn0._AcL-3umdolg-ihWE4PJbg#695,%205th%20Main%20Road,%20OMBR%20Layout,%20Banaswadi%20Ring%20Road%20Near%20BABY%20Cart,%20chaya%20Hospital%20Road,%20Call%20to%208861688882,%20Bengaluru,%20Karnataka%20560043,%20India.json
# 6880it [14:25,  7.95it/s]
# 위치 정보 처리 결과:
#    current_latitude  current_longitude current_district current_region  \
# 0         12.678486          78.620490       Tirupathur     Tamil Nadu
# 1         13.130806          80.153871          Chennai     Tamil Nadu
# 2         13.078467          80.226052          Chennai     Tamil Nadu
# 3         12.966904          79.945450     Kancheepuram     Tamil Nadu
# 4         12.431572          79.820528     Chengalpattu     Tamil Nadu
#
#   current_country
# 0           India
# 1           India
# 2           India
# 3           India
# 4           India

# %%
def des_locations(df, key):
    """
    데이터프레임의 주소들에 대해 위도와 경도를 추출
    """
    # 데이터프레임 길이만큼 None으로 초기화
    df_des_lat = [None] * len(df)
    df_des_lng = [None] * len(df)
    df_des_district = [None] * len(df)
    df_des_region = [None] * len(df)
    df_des_country = [None] * len(df)
    
    api_key = key
    
    for idx, row in tqdm(df.iterrows()):
        if pd.notna(row['destinationlocation']):
            try:
                # geocoder로 위치 정보 요청
                g = geocoder.mapbox(row['destinationlocation'], key=api_key)
                result = g.json
        
                # status가 'OK'인 경우에만 좌표 저장
                if result and result.get('status') == 'OK':
                    df_des_lat[idx] = result.get('lat')
                    df_des_lng[idx] = result.get('lng')
                    df_des_district[idx] = result.get('raw', {}).get('district')
                    df_des_region[idx] = result.get('raw', {}).get('region')
                    df_des_country[idx] = result.get('raw', {}).get('country')
                
                # API 요청 제한 준수를 위한 대기
                time.sleep(0.1)
                
            except Exception as e:
                print(f"Error processing row {idx}: {e}")
                continue
                
    return pd.Series(df_des_lat), pd.Series(df_des_lng), pd.Series(df_des_district), pd.Series(df_des_region), pd.Series(df_des_country)

# %%
# 함수 실행
df['destination_latitude'], df['destination_longitude'], df['destination_district'], df['destination_region'], df['destination_country'] = des_locations(df)

# 결과 확인
print("\n위치 정보 처리 결과:")
des_columns = ['destination_latitude', 'destination_longitude', 'destination_district', 'current_region', 'destination_country']
print(df[des_columns].head())
# Out:
# 6880it [18:20,  6.25it/s]
# 위치 정보 처리 결과:
#    destination_latitude  destination_longitude destination_district  \
# 0             13.203359              78.184354                Kolar
# 1             12.996738              80.153561         Kancheepuram
# 2             11.935623              79.829230           Puducherry
# 3             12.996738              80.153561         Kancheepuram
# 4             11.935623              79.829230           Puducherry
#
#   current_region destination_country
# 0     Tamil Nadu               India
# 1     Tamil Nadu               India
# 2     Tamil Nadu               India
# 3     Tamil Nadu               India
# 4     Tamil Nadu               India

# %%
df.head(10)
# Out:
#      gpsprovider           bookingid           bookingidDate   vehicleNo  \
# 0  CONSENT TRACK  MVCV0000927/082021 2020-08-17 14:59:01.000    KA590408
# 1        VAMOSYS  VCV00014271/082021 2020-08-27 16:22:22.827  TN30BC5917
# 2  CONSENT TRACK  VCV00014382/082021 2020-08-27 17:59:25.000  TN22AR2748
# 3        VAMOSYS  VCV00014743/082021 2020-08-28 00:48:24.503  TN28AQ0781
# 4        VAMOSYS  VCV00014744/082021 2020-08-28 01:23:19.243   TN68F1722
# 5        VAMOSYS  VCV00014749/082021 2020-08-28 02:14:22.640   TN88A4980
# 6        VAMOSYS  VCV00014750/082021 2020-08-28 02:20:27.530   TN88C8204
# 7        VAMOSYS  VCV00014812/082021 2020-08-28 09:22:31.377   TN88D4133
# 8  CONSENT TRACK  MVCV0001769/082021 2020-08-28 09:38:30.000  TN23AM4662
# 9        VAMOSYS  VCV00014665/082021 2020-08-27 22:27:54.427  TN30BC5982
#
#                                       originLocation  \
# 0               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 5  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 6  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 7  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 8            ASHOK LEYLAND ENNORE,CHENNAI,TAMIL NADU
# 9  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
#
#                                  destinationLocation        orgLatLon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8710,79.7390
# 3  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 4              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8720,79.6320
# 5  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 6  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 7  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 8        ASHOK LEYLAND PLANT 2-HOSUR,HOSUR,KARNATAKA  13.2150,80.3200
# 9  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
#
#          desLatLon  org_latitude  org_longitude  ... current_latitude  \
# 0  12.7400,77.8200        13.155         80.196  ...        12.678486
# 1  12.8390,79.9540        12.839         79.954  ...        13.130806
# 2  11.8710,79.7390        11.871         79.739  ...        13.078467
# 3  12.8390,79.9540        12.839         79.954  ...        12.966904
# 4  11.8720,79.6320        11.872         79.632  ...        12.431572
# 5  12.8390,79.9540        12.839         79.954  ...        13.058455
# 6  12.8390,79.9540        12.839         79.954  ...        11.622803
# 7  12.8390,79.9540        12.839         79.954  ...        12.966904
# 8  12.7660,77.7860        13.215         80.320  ...        12.812338
# 9  12.8390,79.9540        12.839         79.954  ...        13.130806
#
#    current_longitude  current_district current_region current_country  \
# 0          78.620490        Tirupathur     Tamil Nadu           India
# 1          80.153871           Chennai     Tamil Nadu           India
# 2          80.226052           Chennai     Tamil Nadu           India
# 3          79.945450      Kancheepuram     Tamil Nadu           India
# 4          79.820528      Chengalpattu     Tamil Nadu           India
# 5          79.975330       Thiruvallur     Tamil Nadu           India
# 6          78.143826             Salem     Tamil Nadu           India
# 7          79.945450      Kancheepuram     Tamil Nadu           India
# 8          78.742625        Tirupathur     Tamil Nadu           India
# 9          80.153871           Chennai     Tamil Nadu           India
#
#   destination_latitude destination_longitude destination_district  \
# 0            13.203359             78.184354                Kolar
# 1            12.996738             80.153561         Kancheepuram
# 2            11.935623             79.829230           Puducherry
# 3            12.996738             80.153561         Kancheepuram
# 4            11.935623             79.829230           Puducherry
# 5            12.996738             80.153561         Kancheepuram
# 6            12.996738             80.153561         Kancheepuram
# 7            12.996738             80.153561         Kancheepuram
# 8            13.203359             78.184354                Kolar
# 9            12.996738             80.153561         Kancheepuram
#
#   destination_region destination_country
# 0          Karnataka               India
# 1         Tamil Nadu               India
# 2         Puducherry               India
# 3         Tamil Nadu               India
# 4         Puducherry               India
# 5         Tamil Nadu               India
# 6         Tamil Nadu               India
# 7         Tamil Nadu               India
# 8          Karnataka               India
# 9         Tamil Nadu               India
#
# [10 rows x 38 columns]

# %%
## 임시 테이블 생성
temp_df = df.copy()

# %%
def calculate_route_distance(df, key):
    """
    현재 위치와 목적지 간의 거리를 계산하는 함수
    """
    # 결과를 저장할 리스트 초기화
    distances = [None] * len(df)
    durations = [None] * len(df)
    
    # Mapbox API 키
    access_token = key
    
    for idx, row in tqdm(df.iterrows()):
        # 모든 좌표가 있는 경우에만 계산
        if pd.notna(row['current_latitude']) and pd.notna(row['current_longitude']) and \
           pd.notna(row['destination_latitude']) and pd.notna(row['destination_longitude']):
            try:
                # API 엔드포인트 구성
                base_url = "https://api.mapbox.com/directions/v5/mapbox/driving"
                coordinates = f"{row['current_longitude']},{row['current_latitude']};" \
                            f"{row['destination_longitude']},{row['destination_latitude']}"
                
                # API 요청 파라미터
                params = {
                    'access_token': access_token,
                    'geometries': 'geojson',
                    'overview': 'full'
                }
                
                # API 요청
                url = f"{base_url}/{coordinates}"
                response = requests.get(url, params=params)
                data = response.json()
                
                if data.get('routes'):
                    route = data['routes'][0]
                    # 거리를 킬로미터로 변환 (API는 미터 단위로 반환)
                    distances[idx] = round(route['distance'] / 1000, 2)
                    # 소요시간을 분으로 변환 (API는 초 단위로 반환)
                    durations[idx] = round(route['duration'] / 60, 2)
                
                # API 요청 제한 준수
                time.sleep(0.1)
                
            except Exception as e:
                print(f"Error processing row {idx}: {e}")
                continue
    
    return pd.Series(distances), pd.Series(durations)

# %%
# 함수 실행
df['cur_des_distance_km'], df['cur_des_duration_min'] = calculate_route_distance(df)

# 결과 확인
print("\n거리 계산 결과:")
print(df[['cur_des_distance_km', 'cur_des_duration_min']].head())
# Out:
# 6880it [31:52,  3.60it/s]
# 거리 계산 결과:
#    cur_des_distance_km  cur_des_duration_min
# 0               120.23                182.61
# 1                20.69                 51.93
# 2               162.91                179.65
# 3                33.90                 62.28
# 4                74.21                 76.54

# %%
df
# Out:
#         gpsprovider           bookingid           bookingidDate   vehicleNo  \
# 0     CONSENT TRACK  MVCV0000927/082021 2020-08-17 14:59:01.000    KA590408
# 1           VAMOSYS  VCV00014271/082021 2020-08-27 16:22:22.827  TN30BC5917
# 2     CONSENT TRACK  VCV00014382/082021 2020-08-27 17:59:25.000  TN22AR2748
# 3           VAMOSYS  VCV00014743/082021 2020-08-28 00:48:24.503  TN28AQ0781
# 4           VAMOSYS  VCV00014744/082021 2020-08-28 01:23:19.243   TN68F1722
# ...             ...                 ...                     ...         ...
# 6875          JTECH        WDSBKTP42751 2019-03-27 17:25:33.000    KA219502
# 6876          JTECH        WDSBKTP43203 2019-03-31 15:02:34.000  KA01AE9163
# 6877          JTECH        WDSBKTP43021 2019-03-29 18:56:26.000  KA01AE9163
# 6878          JTECH        WDSBKTP42685 2019-03-27 08:29:45.000   KA21A3643
# 6879          JTECH        WDSBKTP42858 2019-03-28 17:55:17.000   KA51D1317
#
#                                          originLocation  \
# 0                  TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875             Ramamurthy Nagar, Bangalore, Karnataka
# 6876             Ramamurthy Nagar, Bangalore, Karnataka
# 6877               Mugabala, Bangalore Rural, Karnataka
# 6878               Mugabala, Bangalore Rural, Karnataka
# 6879               Mugabala, Bangalore Rural, Karnataka
#
#                                     destinationLocation  \
# 0          ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA
# 1     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3     DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4                 LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# ...                                                 ...
# 6875            Sahakaranagar P.O, Bangalore, Karnataka
# 6876  Bangalore International Airport, Bangalore, Ka...
# 6877                       Anekal, Bangalore, Karnataka
# 6878                       Anekal, Bangalore, Karnataka
# 6879                       Anekal, Bangalore, Karnataka
#
#                                   orgLatLon  \
# 0                           13.1550,80.1960
# 1                           12.8390,79.9540
# 2                           11.8710,79.7390
# 3                           12.8390,79.9540
# 4                           11.8720,79.6320
# ...                                     ...
# 6875  13.007503209603689,77.665098855934886
# 6876  13.007503209603689,77.665098855934886
# 6877  16.560192249175344,80.792293091599547
# 6878  16.560192249175344,80.792293091599547
# 6879  16.560192249175344,80.792293091599547
#
#                                   desLatLon  org_latitude  org_longitude  ...  \
# 0                           12.7400,77.8200     13.155000      80.196000  ...
# 1                           12.8390,79.9540     12.839000      79.954000  ...
# 2                           11.8710,79.7390     11.871000      79.739000  ...
# 3                           12.8390,79.9540     12.839000      79.954000  ...
# 4                           11.8720,79.6320     11.872000      79.632000  ...
# ...                                     ...           ...            ...  ...
# 6875  13.068901840235711,77.590655738806618     13.007503      77.665099  ...
# 6876  13.196312912801169,77.708156925688726     13.007503      77.665099  ...
# 6877                    12.722686,77.676518     16.560192      80.792293  ...
# 6878  12.896896847817695,77.712223056874862     16.560192      80.792293  ...
# 6879  13.199089183304451,77.708554234959038     16.560192      80.792293  ...
#
#      current_district  current_region  current_country destination_latitude  \
# 0          Tirupathur      Tamil Nadu            India            13.203359
# 1             Chennai      Tamil Nadu            India            12.996738
# 2             Chennai      Tamil Nadu            India            11.935623
# 3        Kancheepuram      Tamil Nadu            India            12.996738
# 4        Chengalpattu      Tamil Nadu            India            11.935623
# ...               ...             ...              ...                  ...
# 6875  Bengaluru Urban       Karnataka            India            12.972662
# 6876  Bengaluru Urban       Karnataka            India            13.198859
# 6877  Bengaluru Urban       Karnataka            India            12.709170
# 6878  Bengaluru Urban       Karnataka            India            12.709170
# 6879  Bengaluru Urban       Karnataka            India            12.709170
#
#      destination_longitude destination_district destination_region  \
# 0                78.184354                Kolar          Karnataka
# 1                80.153561         Kancheepuram         Tamil Nadu
# 2                79.829230           Puducherry         Puducherry
# 3                80.153561         Kancheepuram         Tamil Nadu
# 4                79.829230           Puducherry         Puducherry
# ...                    ...                  ...                ...
# 6875             77.656662      Bengaluru Urban          Karnataka
# 6876             77.711030      Bengaluru Rural          Karnataka
# 6877             77.698235      Bengaluru Urban          Karnataka
# 6878             77.698235      Bengaluru Urban          Karnataka
# 6879             77.698235      Bengaluru Urban          Karnataka
#
#      destination_country cur_des_distance_km cur_des_duration_min
# 0                  India              120.23               182.61
# 1                  India               20.69                51.93
# 2                  India              162.91               179.65
# 3                  India               33.90                62.28
# 4                  India               74.21                76.54
# ...                  ...                 ...                  ...
# 6875               India               12.40                36.96
# 6876               India               32.96                61.40
# 6877               India               42.10                94.46
# 6878               India               42.10                94.46
# 6879               India               36.68                82.67
#
# [6880 rows x 40 columns]

# %%
#df.to_excel('/Users/howsang/Documents/002.Study/001.project/001.internship/p_truck_delivery/data/delivery_data_sample_250127_v3.0.xlsx', index=False)
